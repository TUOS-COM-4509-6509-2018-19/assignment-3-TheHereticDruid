# %% [markdown]
# # Linear Algebra and Linear Regression
#
# ### 13th October 2015 Neil Lawrence
#
#
# ## Sum of Squares Error
#
# Last week we considered a cost function for minimization of the error. We considered items (films) and users and assumed that each movie rating, $y_{i,j}$ could be summarised by an inner product between a vector associated with the item, $\mathbf{v}_j$ and one associated with the user $
# \mathbf{u}_i$. We justified the inner product as a measure of similarity in the space of 'movie subjects', where both the users and the items lived, giving the analogy of a library.
#
# To make predictions we encouraged the similarity to be high if the movie rating was high using the quadratic error function,
# $$
# E_{i,j}(\mathbf{u}_i, \mathbf{v}_j) = \left(\mathbf{u}_i^\top \mathbf{v}_j - y_{i,j}\right)^2,
# $$
# which we then summed across all the observations to form the total error
# $$
# E(\mathbf{U}, \mathbf{V}) = \sum_{i,j}s_{i,j}\left(\mathbf{u}_i^\top \mathbf{v}_j - y_{i,j}\right)^2,
# $$
# where $s_{i,j}$ is an indicator variable which is set to 1 if the rating of movie $j$ by user $i$ is provided in our data set.
#
# This is known as a sum of squares error. Minimizing it was first proposed by [Legendre](http://en.wikipedia.org/wiki/Adrien-Marie_Legendre) in 1805. His book, which was on the orbit of comets, is available on google books, we can take a look at the relevant page by calling the code below.

# %%
import pods
pods.notebook.display_google_book(id='spcAAAAAMAAJ', page=72)
# Out:
# <iframe frameborder="0" scrolling="yes" style="border:0px" src="http://books.google.co.uk/books?id=spcAAAAAMAAJ&pg=PA72&output=embed", width=700 height=500></iframe>

# %% [markdown]
# Of course, the main text is in French, but the key part we are interested in can be roughly translated as
#
# "In most matters where we take measures data through observation, the most accurate results they can offer, it is almost always leads to a system of equations of the form
# $$E = a + bx + cy + fz + etc .$$
# where a, b, c, f etc are the known coefficients and  x , y, z etc are unknown and must be determined by the condition that the value of E is reduced, for each equation, to an amount or zero or very small."
#
# He continues
#
# "Of all the principles that we can offer for this item, I think it is not broader, more accurate, nor easier than the one we have used in previous research application, and that is to make the minimum sum of the squares of the errors. By this means, it is between the errors a kind of balance that prevents extreme to prevail, is very specific to make known the state of the closest to the truth system. The sum of the squares of the errors $E^2 + \left.E^\prime\right.^2 + \left.E^{\prime\prime}\right.^2 + etc$ being
# \begin{align*}   &(a + bx + cy + fz + etc)^2 \\
# + &(a^\prime + b^\prime x + c^\prime y + f^\prime z + etc ) ^2\\
# + &(a^{\prime\prime} + b^{\prime\prime}x  + c^{\prime\prime}y +  f^{\prime\prime}z + etc )^2 \\
# + & etc
# \end{align*}
# if we wanted a minimum, by varying x alone, we will have the equation ..."
#
# This is the earliest know printed version of the problem of least squares. The notation, however, is a little awkward for mordern eyes. In particular Legendre doesn't make use of the sum sign,
# $$
# \sum_{i=1}^3 z_i = z_1 + z_2 + z_3
# $$
# nor does he make use of the inner product.
#
# In our notation, if we were to do linear regression, we would need to subsititue:
# \begin{align*}
# a &\leftarrow y_1-c, \\ a^\prime &\leftarrow y_2-c,\\ a^{\prime\prime} &\leftarrow y_3 -c,\\
# \text{etc.}
# \end{align*}
# to introduce the data observations $\{y_i\}_{i=1}^{n}$ alongside $c$, the offset. We would then introduce the input locations
# \begin{align*}
# b & \leftarrow x_1,\\
# b^\prime & \leftarrow x_2,\\
# b^{\prime\prime} & \leftarrow x_3\\
# \text{etc.}
# \end{align*}
# and finally the gradient of the function
# $$x \leftarrow -m.$$
# The remaining coefficients ($c$ and $f$) would then be zero. That would give us
# \begin{align*}   &(y_1 - (mx_1+c))^2 \\
# + &(y_2 -(mx_2 + c))^2\\
# + &(y_3 -(mx_3 + c))^2 \\
# + & \text{etc.}
# \end{align*}
# which we would write in the modern notation for sums as
# $$
# \sum_{i=1}^n (y_i-(mx_i + c))^2
# $$
# which is recognised as the sum of squares error for a linear regression.
#
# This shows the advantage of modern [summation operator](http://en.wikipedia.org/wiki/Summation), $\sum$,  in keeping our mathematical notation compact. Whilst it may look more complicated the first time you see it, understanding the mathematical rules that go around it, allows us to go much further with the notation.
#
# Inner products (or [dot products](http://en.wikipedia.org/wiki/Dot_product)) are similar. They allow us to write
# $$
# \sum_{i=1}^q u_i v_i
# $$
# in a more compact notation,
# $
# \mathbf{u}\cdot\mathbf{v}.
# $
#
# Here we are using bold face to represent vectors, and we assume that the individual elements of a vector $\mathbf{z}$ are given as a series of scalars
# $$
# \mathbf{z} = \begin{bmatrix} z_1\\ z_2\\ \vdots\\ z_n \end{bmatrix}
# $$
# which are each indexed by their position in the vector.
#
# ## Linear Algebra
#
# Linear algebra provides a very similar role, when we introduce [linear algebra](http://en.wikipedia.org/wiki/Linear_algebra), it is because we are faced with a large number of addition and multiplication operations. These operations need to be done together and would be very tedious to write down as a group. So the first reason we reach for linear algebra is for a more compact representation of our mathematical formulae.

# %% [markdown]
# ### Running Example: Olympic Marathons
#
# Now we will load in the Olympic marathon data. This is data of the olympic marath times for the men's marathon from the first olympics in 1896 up until the London 2012 olympics.

# %%
data = pods.datasets.olympic_marathon_men()
x = data['X']
y = data['Y']
# Out:
# Acquiring resource: olympic_marathon_men
#
# Details of data:
# Olympic mens' marathon gold medal winning times from 1896 to 2012. Time given in pace (minutes per kilometer). Data is originally downloaded and collated from Wikipedia, we are not responsible for errors in the data
#
# After downloading the data will take up 584 bytes of space.
#
# Data will be stored in C:\Users\Druid/ods_data_cache/olympic_marathon_men.
#
# Do you wish to proceed with the download? [yes/no]
# yes
# Downloading  http://staffwww.dcs.shef.ac.uk/people/N.Lawrence/dataset_mirror/olympic_marathon_men/olympicMarathonTimes.csv -> C:\Users\Druid/ods_data_cache/olympic_marathon_men\olympicMarathonTimes.csv
# [==============================]   0.001/0.001MB

# %% [markdown]
# You can see what these values are by typing:

# %%
print(x)
print(y)
# Out:
# [[1896.]
#  [1900.]
#  [1904.]
#  [1908.]
#  [1912.]
#  [1920.]
#  [1924.]
#  [1928.]
#  [1932.]
#  [1936.]
#  [1948.]
#  [1952.]
#  [1956.]
#  [1960.]
#  [1964.]
#  [1968.]
#  [1972.]
#  [1976.]
#  [1980.]
#  [1984.]
#  [1988.]
#  [1992.]
#  [1996.]
#  [2000.]
#  [2004.]
#  [2008.]
#  [2012.]]
# [[4.47083333]
#  [4.46472926]
#  [5.22208333]
#  [4.15467867]
#  [3.90331675]
#  [3.56951267]
#  [3.82454477]
#  [3.62483707]
#  [3.59284275]
#  [3.53880792]
#  [3.67010309]
#  [3.39029111]
#  [3.43642612]
#  [3.20583007]
#  [3.13275665]
#  [3.32819844]
#  [3.13583758]
#  [3.0789588 ]
#  [3.10581822]
#  [3.06552909]
#  [3.09357349]
#  [3.16111704]
#  [3.14255244]
#  [3.08527867]
#  [3.10265829]
#  [2.99877553]
#  [3.03392977]]

# %% [markdown]
# Note that they are not `pandas` data frames for this example, they are just arrays of dimensionality $n\times 1$, where $n$ is the number of data.

# %% [markdown]
# The aim of this lab is to have you coding linear regression in python. We will do it in two ways, once using iterative updates (coordinate ascent) and then using linear algebra. The linear algebra approach will not only work much better, it is easy to extend to multiple input linear regression and *non-linear* regression using basis functions.

# %% [markdown]
# ### Plotting the Data
#
# You can make a plot of $y$ vs $x$ with the following command:

# %%
# %matplotlib inline 
import pylab as plt

plt.plot(x, y, 'rx')
plt.xlabel('year')
plt.ylabel('pace in min/km')
# Out:
# Text(0, 0.5, 'pace in min/km')

# %% [markdown]
# ### Maximum Likelihood: Iterative Solution

# %% [markdown]
# Now we will take the maximum likelihood approach we derived in the lecture to fit a line, $y_i=mx_i + c$, to the data you've plotted. We are trying to minimize the error function:

# %% [markdown]
# $$E(m, c) =  \sum_{i=1}^n(y_i-mx_i-c)^2$$

# %% [markdown]
# with respect to $m$, $c$ and $\sigma^2$. We can start with an initial guess for $m$,

# %%
m = -0.4
c = 80

# %% [markdown]
# Then we use the maximum likelihood update to find an estimate for the offset, $c$.
#
# ### Coordinate Descent
#
# In the movie recommender system example, we minimised the objective function by steepest descent based gradient methods. Our updates required us to compute the gradient at the position we were located, then to update the gradient according to the direction of steepest descent. This time, we will take another approach. It is known as *coordinate descent*. In coordinate descent, we choose to move one parameter at a time. Ideally, we design an algorithm that at each step moves the parameter to its minimum value. At each step we choose to move the individual parameter to its minimum.
#
# To find the minimum, we look for the point in the curve where the gradient is zero. This can be found by taking the gradient of $E(m,c)$ with respect to the parameter.
#
# #### Update for Offset
#
# Let's consider the parameter $c$ first. The gradient goes nicely through the summation operator, and we obtain
# $$
# \frac{\text{d}E(m,c)}{\text{d}c} = -\sum_{i=1}^n 2(y_i-mx_i-c).
# $$
# Now we want the point that is a minimum. A minimum is an example of a [*stationary point*](http://en.wikipedia.org/wiki/Stationary_point), the stationary points are those points of the function where the gradient is zero. They are found by solving the equation for $\frac{\text{d}E(m,c)}{\text{d}c} = 0$. Substituting in to our gradient, we can obtain the following equation,
# $$
# 0 = -\sum_{i=1}^n 2(y_i-mx_i-c)
# $$
# which can be reorganised as follows,
# $$
# c^* = \frac{\sum_{i=1}^n(y_i-m^*x_i)}{n}.
# $$
# The fact that the stationary point is easily extracted in this manner implies that the solution is *unique*. There is only one stationary point for this system. Traditionally when trying to determine the type of stationary point we have encountered we now compute the *second derivative*,
# $$
# \frac{\text{d}^2E(m,c)}{\text{d}c^2} = 2n.
# $$
# The second derivative is positive, which in turn implies that we have found a minimum of the function. This means that setting $c$ in this way will take us to the lowest point along that axes.

# %%
# set c to the minimum
c = (y - m*x).mean()
print(c)
# Out:
# 786.0197711453593

# %% [markdown]
# #### Update for Slope
#
# Now we have the offset set to the minimum value, in coordinate descent, the next step is to optimise another parameter. Only one further parameter remains. That is the slope of the system.
#
# Now we can turn our attention to the slope. We once again peform the same set of computations to find the minima. We end up with an update equation of the following form.
#
# $$m^* = \frac{\sum_{i=1}^n (y_i - c)x_i}{\sum_{i=1}^n x_i^2}$$
#
# Communication of mathematics in data science is an essential skill, in a moment, you will be asked to rederive the equation above. Before we do that, however, we will briefly review how to write mathematics in the notebook.
#
# ### $\LaTeX$ for Maths
#
# These cells use [Markdown format](http://en.wikipedia.org/wiki/Markdown). You can include maths in your markdown using [$\LaTeX$ syntax](http://en.wikipedia.org/wiki/LaTeX), all you have to do is write your answer inside dollar signs, as follows:
#
# To write a fraction, we write `$\frac{a}{b}$`, and it will display like this $\frac{a}{b}$. To write a subscript we write `$a_b$` which will appear as $a_b$. To write a superscript (for example in a polynomial) we write `$a^b$` which will appear as $a^b$. There are lots of other macros as well, for example we can do greek letters such as `$\alpha, \beta, \gamma$` rendering as $\alpha, \beta, \gamma$. And we can do sum and intergral signs as `$\sum \int \int$`.
#
# You can combine many of these operations together for composing expressions.

# %% [markdown]
# ### Assignment Question 1
#
# Convert the following python code expressions into $\LaTeX$j, writing your answers below. In each case write your answer as a single equality (i.e. your maths should only contain one expression, not several lines of expressions). For the purposes of your $\LaTeX$ please assume that `x` and `w` are $n$ dimensional vectors.
#
# (a)
# ``` python
# f = x.sum()
# ```
#
# (b)
# ``` python
# m = x.mean()
# ```
#
# (c)
# ``` python
# g = (x*w).sum()
# ```
#
# *15 marks*

# %% [markdown]
# #### Question 1 Answer
#
# Assuming that x and w are vectors of length n, and not matrices of dimension n. Assuming also that question c is a dot product.
#
# (a)
# $$
# f = \sum_{i=i}^n x_i
# $$
#
# (b)
# $$
# m = \frac{\sum_{i=i}^n x_i}{n}
# $$
#
# (c)
# $$
# g = \sum_{i=i}^n x_i w_i
# $$

# %% [markdown]
# ### Gradient With Respect to the Slope
# Now that you've had a little training in writing maths with $\LaTeX$, we will be able to use it to answer questions. The next thing we are going to do is a little differentiation practice.

# %% [markdown]
# ### Assignment Question 2
#
# Derive the the gradient of the objective function with respect to the slope, $m$. Rearrange it to show that the update equation written above does find the stationary points of the objective function. By computing its derivative show that it's a minimum.
#
# *20 marks*

# %% [markdown]
# #### Question 2 Answer
#
# $$
# E(m, c) =  \sum_{i=1}^n(y_i-mx_i-c)^2
# $$
#
# To find the update fuction, we use the following, derived in part with the chain rule
#
# $$
# \frac{\text{d}E(m,c)}{\text{d}m} = -\sum_{i=1}^n 2x_i(y_i-mx_i-c) = 0
# $$
#
# $$
# 0 = \sum_{i=1}^n(y_i-mx_i-c)x_i = \sum_{i=1}^n(y_i-c)x_i - m\sum_{i=1}^nx_i^2
# $$
#
# $$
# m\sum_{i=1}^n(x_i^2) = \sum_{i=1}^n(y_i-c)x_i
# $$
#
# $$
# m = \frac{\sum_{i=1}^n(y_i-c)x_i}{\sum_{i=1}^nx_i^2}
# $$
#
# We see that this equation matches the one provided above. To show that the result is a minimum, we will need to prove that the below is positive
#
# $$
# \frac{\text{d}^2E(m,c)}{\text{d}m^2} = \frac{\text{d}\frac{\text{d}E(m,c)}{\text{d}m}}{\text{d}m} = \frac{\text{d}(-\sum_{i=1}^n 2x_i(y_i-mx_i-c))}{\text{d}m}
# $$
#
# $$
# \frac{\text{d}^2E(m,c)}{\text{d}m^2} = 2\sum_{i=1}^n x_i^2
# $$
#
# Given that all values of x are real values, $x^2$ is always positive by virtue of being a square, and so the term above, as a sum of positive numbers, is always positive, thus proving that the derivative is a minimum. The differentiation involves using the product rule of differentiation, which is
#
# $$
# \frac{\text{d}f(x)g(x)}{\text{d}x} = f(x)\frac{\text{d}g(x)}{\text{d}x} + g(x)\frac{\text{d}f(x)}{\text{d}x}
# $$
#
# The chain rule, used elsewhere above is defined as
#
# $$
# \frac{\text{d}f(g(x))}{\text{d}x} = \frac{\text{d}f(g(x))}{\text{d}g(x)}\frac{\text{d}g(x)}{\text{d}x}
# $$

# %%
m = ((y - c)*x).sum()/(x**2).sum()
print(m)
# Out:
# -0.0390952532504467

# %% [markdown]
# We can have a look at how good our fit is by computing the prediction across the input space. First create a vector of 'test points',

# %%
import numpy as np
x_test = np.linspace(1890, 2020, 130)[:, None]

# %% [markdown]
# Now use this vector to compute some test predictions,

# %%
f_test = m*x_test + c

# %% [markdown]
# Now plot those test predictions with a blue line on the same plot as the data,

# %%
plt.plot(x_test, f_test, 'b-')
plt.plot(x, y, 'rx')

# %% [markdown]
# The fit isn't very good, we need to iterate between these parameter updates in a loop to improve the fit, we have to do this several times,

# %%
for i in np.arange(10):
    m = ((y - c)*x).sum()/(x*x).sum()
    c = (y-m*x).sum()/y.shape[0]
print(m)
print(c)
# Out:
# -0.3987259642505432
# 783.5273797273478

# %% [markdown]
# And let's try plotting the result again

# %%
f_test = m*x_test + c
plt.plot(x_test, f_test, 'b-')
plt.plot(x, y, 'rx')

# %% [markdown]
# Clearly we need more iterations than 10! In the next question you will add more iterations and report on the error as optimisation proceeds.

# %% [markdown]
# ### Assignment Question 3
#
# There is a problem here, we seem to need many interations to get to a good solution. Let's explore what's going on. Write code which alternates between updates of `c` and `m`. Include the following features in your code.
#
# (a) Initialise with `m=-0.4` and `c=80`.
# (b) Every 10 iterations compute the value of the objective function for the training data and print it to the screen (you'll find hints on this in the lab from last week.
# (c) Cause the code to stop running when the error change over less than 10 iterations is smaller than $1\times10^{-4}$. This is known as a stopping criterion.
#
# Why do we need so many iterations to get to the solution?
#
# *25 marks*

# %%
# Question 3 Answer Code
# Write code for you answer to this question in this box
# Do not delete these comments, otherwise you will get zero for this answer.
# Make sure your code has run and the answer is correct *before* submitting your notebook for marking.

m = -0.4 # (a)
c = 80
old_obj="NA"
for i in np.arange(10000):
    print("External iteration",i) # Each exteral iteration is 20 actual iterations
    for j in np.arange(10): # (b) for m iterations
        m = ((y - c)*x).sum()/(x*x).sum()
    new_obj=((y-m*x-c)**2).sum()
    if(old_obj!="NA" and old_obj-new_obj<0.0001): # (c)
        break
    old_obj=new_obj
    for j in np.arange(10): # (b) for c iterations
        c = (y-m*x).sum()/y.shape[0]
    new_obj=((y-m*x-c)**2).sum()
    if(old_obj!="NA" and old_obj-new_obj<0.0001): # (c)
        break
    old_obj=new_obj
f_test = m*x_test + c
plt.plot(x_test, f_test, 'b-')
plt.plot(x, y, 'rx')

# The above is alternating between m and c iterations, which proves to be about 11 times less effective in terms of iteration count than updating both in the same set of iterations. I provide the code for this case below.
# Replace the external for loop with the following
# for i in np.arange(10000):
#     print("External iteration",i) # Each exteral iteration is 10 actual iterations
#     for j in np.arange(10): # (b)
#         m = ((y - c)*x).sum()/(x*x).sum()
#         c = (y-m*x).sum()/y.shape[0]
#     new_obj=((y-m*x-c)**2).sum()
#     if(old_obj!="NA" and old_obj-new_obj<0.0001): # (c)
#         break
#     old_obj=new_obj
# It should be noted here that there is a dependency between m and c, and that the first update on c uses a value of m which has already been updated once. This simply means that the updates for c are essentially one update ahead of those for m
# Out:
# External iteration 0
# External iteration 1
# External iteration 2
# External iteration 3
# External iteration 4
# External iteration 5
# External iteration 6
# External iteration 7
# External iteration 8
# External iteration 9
# External iteration 10
# External iteration 11
# External iteration 12
# External iteration 13
# External iteration 14
# External iteration 15
# External iteration 16
# External iteration 17
# External iteration 18
# External iteration 19
# External iteration 20
# External iteration 21
# External iteration 22
# External iteration 23
# External iteration 24
# External iteration 25
# External iteration 26
# External iteration 27
# External iteration 28
# External iteration 29
# External iteration 30
# External iteration 31
# External iteration 32
# External iteration 33
# External iteration 34
# External iteration 35
# External iteration 36
# External iteration 37
# External iteration 38
# External iteration 39
# External iteration 40
# External iteration 41
# External iteration 42
# External iteration 43
# External iteration 44
# External iteration 45
# External iteration 46
# External iteration 47
# External iteration 48
# External iteration 49
# External iteration 50
# External iteration 51
# External iteration 52
# External iteration 53
# External iteration 54
# External iteration 55
# External iteration 56
# External iteration 57
# External iteration 58
# External iteration 59
# External iteration 60
# External iteration 61
# External iteration 62
# External iteration 63
# External iteration 64
# External iteration 65
# External iteration 66
# External iteration 67
# External iteration 68
# External iteration 69
# External iteration 70
# External iteration 71
# External iteration 72
# External iteration 73
# External iteration 74
# External iteration 75
# External iteration 76
# External iteration 77
# External iteration 78
# External iteration 79
# External iteration 80
# External iteration 81
# External iteration 82
# External iteration 83
# External iteration 84
# External iteration 85
# External iteration 86
# External iteration 87
# External iteration 88
# External iteration 89
# External iteration 90
# External iteration 91
# External iteration 92
# External iteration 93
# External iteration 94
# External iteration 95
# External iteration 96
# External iteration 97
# External iteration 98
# External iteration 99
# External iteration 100
# External iteration 101
# External iteration 102
# External iteration 103
# External iteration 104
# External iteration 105
# External iteration 106
# External iteration 107
# External iteration 108
# External iteration 109
# External iteration 110
# External iteration 111
# External iteration 112
# External iteration 113
# External iteration 114
# External iteration 115
# External iteration 116
# External iteration 117
# External iteration 118
# External iteration 119
# External iteration 120
# External iteration 121
# External iteration 122
# External iteration 123
# External iteration 124
# External iteration 125
# External iteration 126
# External iteration 127
# External iteration 128
# External iteration 129
# External iteration 130
# External iteration 131
# External iteration 132
# External iteration 133
# External iteration 134
# External iteration 135
# External iteration 136
# External iteration 137
# External iteration 138
# External iteration 139
# External iteration 140
# External iteration 141
# External iteration 142
# External iteration 143
# External iteration 144
# External iteration 145
# External iteration 146
# External iteration 147
# External iteration 148
# External iteration 149
# External iteration 150
# External iteration 151
# External iteration 152
# External iteration 153
# External iteration 154
# External iteration 155
# External iteration 156
# External iteration 157
# External iteration 158
# External iteration 159
# External iteration 160
# External iteration 161
# External iteration 162
# External iteration 163
# External iteration 164
# External iteration 165
# External iteration 166
# External iteration 167
# External iteration 168
# External iteration 169
# External iteration 170
# External iteration 171
# External iteration 172
# External iteration 173
# External iteration 174
# External iteration 175
# External iteration 176
# External iteration 177
# External iteration 178
# External iteration 179
# External iteration 180
# External iteration 181
# External iteration 182
# External iteration 183
# External iteration 184
# External iteration 185
# External iteration 186
# External iteration 187
# External iteration 188
# External iteration 189
# External iteration 190
# External iteration 191
# External iteration 192
# External iteration 193
# External iteration 194
# External iteration 195
# External iteration 196
# External iteration 197
# External iteration 198
# External iteration 199
# External iteration 200
# External iteration 201
# External iteration 202
# External iteration 203
# External iteration 204
# External iteration 205
# External iteration 206
# External iteration 207
# External iteration 208
# External iteration 209
# External iteration 210
# External iteration 211
# External iteration 212
# External iteration 213
# External iteration 214
# External iteration 215
# External iteration 216
# External iteration 217
# External iteration 218
# External iteration 219
# External iteration 220
# External iteration 221
# External iteration 222
# External iteration 223
# External iteration 224
# External iteration 225
# External iteration 226
# External iteration 227
# External iteration 228
# External iteration 229
# External iteration 230
# External iteration 231
# External iteration 232
# External iteration 233
# External iteration 234
# External iteration 235
# External iteration 236
# External iteration 237
# External iteration 238
# External iteration 239
# External iteration 240
# External iteration 241
# External iteration 242
# External iteration 243
# External iteration 244
# External iteration 245
# External iteration 246
# External iteration 247
# External iteration 248
# External iteration 249
# External iteration 250
# External iteration 251
# External iteration 252
# External iteration 253
# External iteration 254
# External iteration 255
# External iteration 256
# External iteration 257
# External iteration 258
# External iteration 259
# External iteration 260
# External iteration 261
# External iteration 262
# External iteration 263
# External iteration 264
# External iteration 265
# External iteration 266
# External iteration 267
# External iteration 268
# External iteration 269
# External iteration 270
# External iteration 271
# External iteration 272
# External iteration 273
# External iteration 274
# External iteration 275
# External iteration 276
# External iteration 277
# External iteration 278
# External iteration 279
# External iteration 280
# External iteration 281
# External iteration 282
# External iteration 283
# External iteration 284
# External iteration 285
# External iteration 286
# External iteration 287
# External iteration 288
# External iteration 289
# External iteration 290
# External iteration 291
# External iteration 292
# External iteration 293
# External iteration 294
# External iteration 295
# External iteration 296
# External iteration 297
# External iteration 298
# External iteration 299
# External iteration 300
# External iteration 301
# External iteration 302
# External iteration 303
# External iteration 304
# External iteration 305
# External iteration 306
# External iteration 307
# External iteration 308
# External iteration 309
# External iteration 310
# External iteration 311
# External iteration 312
# External iteration 313
# External iteration 314
# External iteration 315
# External iteration 316
# External iteration 317
# External iteration 318
# External iteration 319
# External iteration 320
# External iteration 321
# External iteration 322
# External iteration 323
# External iteration 324
# External iteration 325
# External iteration 326
# External iteration 327
# External iteration 328
# External iteration 329
# External iteration 330
# External iteration 331
# External iteration 332
# External iteration 333
# External iteration 334
# External iteration 335
# External iteration 336
# External iteration 337
# External iteration 338
# External iteration 339
# External iteration 340
# External iteration 341
# External iteration 342
# External iteration 343
# External iteration 344
# External iteration 345
# External iteration 346
# External iteration 347
# External iteration 348
# External iteration 349
# External iteration 350
# External iteration 351
# External iteration 352
# External iteration 353
# External iteration 354
# External iteration 355
# External iteration 356
# External iteration 357
# External iteration 358
# External iteration 359
# External iteration 360
# External iteration 361
# External iteration 362
# External iteration 363
# External iteration 364
# External iteration 365
# External iteration 366
# External iteration 367
# External iteration 368
# External iteration 369
# External iteration 370
# External iteration 371
# External iteration 372
# External iteration 373
# External iteration 374
# External iteration 375
# External iteration 376
# External iteration 377
# External iteration 378
# External iteration 379
# External iteration 380
# External iteration 381
# External iteration 382
# External iteration 383
# External iteration 384
# External iteration 385
# External iteration 386
# External iteration 387
# External iteration 388
# External iteration 389
# External iteration 390
# External iteration 391
# External iteration 392
# External iteration 393
# External iteration 394
# External iteration 395
# External iteration 396
# External iteration 397
# External iteration 398
# External iteration 399
# External iteration 400
# External iteration 401
# External iteration 402
# External iteration 403
# External iteration 404
# External iteration 405
# External iteration 406
# External iteration 407
# External iteration 408
# External iteration 409
# External iteration 410
# External iteration 411
# External iteration 412
# External iteration 413
# External iteration 414
# External iteration 415
# External iteration 416
# External iteration 417
# External iteration 418
# External iteration 419
# External iteration 420
# External iteration 421
# External iteration 422
# External iteration 423
# External iteration 424
# External iteration 425
# External iteration 426
# External iteration 427
# External iteration 428
# External iteration 429
# External iteration 430
# External iteration 431
# External iteration 432
# External iteration 433
# External iteration 434
# External iteration 435
# External iteration 436
# External iteration 437
# External iteration 438
# External iteration 439
# External iteration 440
# External iteration 441
# External iteration 442
# External iteration 443
# External iteration 444
# External iteration 445
# External iteration 446
# External iteration 447
# External iteration 448
# External iteration 449
# External iteration 450
# External iteration 451
# External iteration 452
# External iteration 453
# External iteration 454
# External iteration 455
# External iteration 456
# External iteration 457
# External iteration 458
# External iteration 459
# External iteration 460
# External iteration 461
# External iteration 462
# External iteration 463
# External iteration 464
# External iteration 465
# External iteration 466
# External iteration 467
# External iteration 468
# External iteration 469
# External iteration 470
# External iteration 471
# External iteration 472
# External iteration 473
# External iteration 474
# External iteration 475
# External iteration 476
# External iteration 477
# External iteration 478
# External iteration 479
# External iteration 480
# External iteration 481
# External iteration 482
# External iteration 483
# External iteration 484
# External iteration 485
# External iteration 486
# External iteration 487
# External iteration 488
# External iteration 489
# External iteration 490
# External iteration 491
# External iteration 492
# External iteration 493
# External iteration 494
# External iteration 495
# External iteration 496
# External iteration 497
# External iteration 498
# External iteration 499
# External iteration 500
# External iteration 501
# External iteration 502
# External iteration 503
# External iteration 504
# External iteration 505
# External iteration 506
# External iteration 507
# External iteration 508
# External iteration 509
# External iteration 510
# External iteration 511
# External iteration 512
# External iteration 513
# External iteration 514
# External iteration 515
# External iteration 516
# External iteration 517
# External iteration 518
# External iteration 519
# External iteration 520
# External iteration 521
# External iteration 522
# External iteration 523
# External iteration 524
# External iteration 525
# External iteration 526
# External iteration 527
# External iteration 528
# External iteration 529
# External iteration 530
# External iteration 531
# External iteration 532
# External iteration 533
# External iteration 534
# External iteration 535
# External iteration 536
# External iteration 537
# External iteration 538
# External iteration 539
# External iteration 540
# External iteration 541
# External iteration 542
# External iteration 543
# External iteration 544
# External iteration 545
# External iteration 546
# External iteration 547
# External iteration 548
# External iteration 549
# External iteration 550
# External iteration 551
# External iteration 552
# External iteration 553
# External iteration 554
# External iteration 555
# External iteration 556
# External iteration 557
# External iteration 558
# External iteration 559
# External iteration 560
# External iteration 561
# External iteration 562
# External iteration 563
# External iteration 564
# External iteration 565
# External iteration 566
# External iteration 567
# External iteration 568
# External iteration 569
# External iteration 570
# External iteration 571
# External iteration 572
# External iteration 573
# External iteration 574
# External iteration 575
# External iteration 576
# External iteration 577
# External iteration 578
# External iteration 579
# External iteration 580
# External iteration 581
# External iteration 582
# External iteration 583
# External iteration 584
# External iteration 585
# External iteration 586
# External iteration 587
# External iteration 588
# External iteration 589
# External iteration 590
# External iteration 591
# External iteration 592
# External iteration 593
# External iteration 594
# External iteration 595
# External iteration 596
# External iteration 597
# External iteration 598
# External iteration 599
# External iteration 600
# External iteration 601
# External iteration 602
# External iteration 603
# External iteration 604
# External iteration 605
# External iteration 606
# External iteration 607
# External iteration 608
# External iteration 609
# External iteration 610
# External iteration 611
# External iteration 612
# External iteration 613
# External iteration 614
# External iteration 615
# External iteration 616
# External iteration 617
# External iteration 618
# External iteration 619
# External iteration 620
# External iteration 621
# External iteration 622
# External iteration 623
# External iteration 624
# External iteration 625
# External iteration 626
# External iteration 627
# External iteration 628
# External iteration 629
# External iteration 630
# External iteration 631
# External iteration 632
# External iteration 633
# External iteration 634
# External iteration 635
# External iteration 636
# External iteration 637
# External iteration 638
# External iteration 639
# External iteration 640
# External iteration 641
# External iteration 642
# External iteration 643
# External iteration 644
# External iteration 645
# External iteration 646
# External iteration 647
# External iteration 648
# External iteration 649
# External iteration 650
# External iteration 651
# External iteration 652
# External iteration 653
# External iteration 654
# External iteration 655
# External iteration 656
# External iteration 657
# External iteration 658
# External iteration 659
# External iteration 660
# External iteration 661
# External iteration 662
# External iteration 663
# External iteration 664
# External iteration 665
# External iteration 666
# External iteration 667
# External iteration 668
# External iteration 669
# External iteration 670
# External iteration 671
# External iteration 672
# External iteration 673
# External iteration 674
# External iteration 675
# External iteration 676
# External iteration 677
# External iteration 678
# External iteration 679
# External iteration 680
# External iteration 681
# External iteration 682
# External iteration 683
# External iteration 684
# External iteration 685
# External iteration 686
# External iteration 687
# External iteration 688
# External iteration 689
# External iteration 690
# External iteration 691
# External iteration 692
# External iteration 693
# External iteration 694
# External iteration 695
# External iteration 696
# External iteration 697
# External iteration 698
# External iteration 699
# External iteration 700
# External iteration 701
# External iteration 702
# External iteration 703
# External iteration 704
# External iteration 705
# External iteration 706
# External iteration 707
# External iteration 708
# External iteration 709
# External iteration 710
# External iteration 711
# External iteration 712
# External iteration 713
# External iteration 714
# External iteration 715
# External iteration 716
# External iteration 717
# External iteration 718
# External iteration 719
# External iteration 720
# External iteration 721
# External iteration 722
# External iteration 723
# External iteration 724
# External iteration 725
# External iteration 726
# External iteration 727
# External iteration 728
# External iteration 729
# External iteration 730
# External iteration 731
# External iteration 732
# External iteration 733
# External iteration 734
# External iteration 735
# External iteration 736
# External iteration 737
# External iteration 738
# External iteration 739
# External iteration 740
# External iteration 741
# External iteration 742
# External iteration 743
# External iteration 744
# External iteration 745
# External iteration 746
# External iteration 747
# External iteration 748
# External iteration 749
# External iteration 750
# External iteration 751
# External iteration 752
# External iteration 753
# External iteration 754
# External iteration 755
# External iteration 756
# External iteration 757
# External iteration 758
# External iteration 759
# External iteration 760
# External iteration 761
# External iteration 762
# External iteration 763
# External iteration 764
# External iteration 765
# External iteration 766
# External iteration 767
# External iteration 768
# External iteration 769
# External iteration 770
# External iteration 771
# External iteration 772
# External iteration 773
# External iteration 774
# External iteration 775
# External iteration 776
# External iteration 777
# External iteration 778
# External iteration 779
# External iteration 780
# External iteration 781
# External iteration 782
# External iteration 783
# External iteration 784
# External iteration 785
# External iteration 786
# External iteration 787
# External iteration 788
# External iteration 789
# External iteration 790
# External iteration 791
# External iteration 792
# External iteration 793
# External iteration 794
# External iteration 795
# External iteration 796
# External iteration 797
# External iteration 798
# External iteration 799
# External iteration 800
# External iteration 801
# External iteration 802
# External iteration 803
# External iteration 804
# External iteration 805
# External iteration 806
# External iteration 807
# External iteration 808
# External iteration 809
# External iteration 810
# External iteration 811
# External iteration 812
# External iteration 813
# External iteration 814
# External iteration 815
# External iteration 816
# External iteration 817
# External iteration 818
# External iteration 819
# External iteration 820
# External iteration 821
# External iteration 822
# External iteration 823
# External iteration 824
# External iteration 825
# External iteration 826
# External iteration 827
# External iteration 828
# External iteration 829
# External iteration 830
# External iteration 831
# External iteration 832
# External iteration 833
# External iteration 834
# External iteration 835
# External iteration 836
# External iteration 837
# External iteration 838
# External iteration 839
# External iteration 840
# External iteration 841
# External iteration 842
# External iteration 843
# External iteration 844
# External iteration 845
# External iteration 846
# External iteration 847
# External iteration 848
# External iteration 849
# External iteration 850
# External iteration 851
# External iteration 852
# External iteration 853
# External iteration 854
# External iteration 855
# External iteration 856
# External iteration 857
# External iteration 858
# External iteration 859
# External iteration 860
# External iteration 861
# External iteration 862
# External iteration 863
# External iteration 864
# External iteration 865
# External iteration 866
# External iteration 867
# External iteration 868
# External iteration 869
# External iteration 870
# External iteration 871
# External iteration 872
# External iteration 873
# External iteration 874
# External iteration 875
# External iteration 876
# External iteration 877
# External iteration 878
# External iteration 879
# External iteration 880
# External iteration 881
# External iteration 882
# External iteration 883
# External iteration 884
# External iteration 885
# External iteration 886
# External iteration 887
# External iteration 888
# External iteration 889
# External iteration 890
# External iteration 891
# External iteration 892
# External iteration 893
# External iteration 894
# External iteration 895
# External iteration 896
# External iteration 897
# External iteration 898
# External iteration 899
# External iteration 900
# External iteration 901
# External iteration 902
# External iteration 903
# External iteration 904
# External iteration 905
# External iteration 906
# External iteration 907
# External iteration 908
# External iteration 909
# External iteration 910
# External iteration 911
# External iteration 912
# External iteration 913
# External iteration 914
# External iteration 915
# External iteration 916
# External iteration 917
# External iteration 918
# External iteration 919
# External iteration 920
# External iteration 921
# External iteration 922
# External iteration 923
# External iteration 924
# External iteration 925
# External iteration 926
# External iteration 927
# External iteration 928
# External iteration 929
# External iteration 930
# External iteration 931
# External iteration 932
# External iteration 933
# External iteration 934
# External iteration 935
# External iteration 936
# External iteration 937
# External iteration 938
# External iteration 939
# External iteration 940
# External iteration 941
# External iteration 942
# External iteration 943
# External iteration 944
# External iteration 945
# External iteration 946
# External iteration 947
# External iteration 948
# External iteration 949
# External iteration 950
# External iteration 951
# External iteration 952
# External iteration 953
# External iteration 954
# External iteration 955
# External iteration 956
# External iteration 957
# External iteration 958
# External iteration 959
# External iteration 960
# External iteration 961
# External iteration 962
# External iteration 963
# External iteration 964
# External iteration 965
# External iteration 966
# External iteration 967
# External iteration 968
# External iteration 969
# External iteration 970
# External iteration 971
# External iteration 972
# External iteration 973
# External iteration 974
# External iteration 975
# External iteration 976
# External iteration 977
# External iteration 978
# External iteration 979
# External iteration 980
# External iteration 981
# External iteration 982
# External iteration 983
# External iteration 984
# External iteration 985
# External iteration 986
# External iteration 987
# External iteration 988
# External iteration 989
# External iteration 990
# External iteration 991
# External iteration 992
# External iteration 993
# External iteration 994
# External iteration 995
# External iteration 996
# External iteration 997
# External iteration 998
# External iteration 999
# External iteration 1000
# External iteration 1001
# External iteration 1002
# External iteration 1003
# External iteration 1004
# External iteration 1005
# External iteration 1006
# External iteration 1007
# External iteration 1008
# External iteration 1009
# External iteration 1010
# External iteration 1011
# External iteration 1012
# External iteration 1013
# External iteration 1014
# External iteration 1015
# External iteration 1016
# External iteration 1017
# External iteration 1018
# External iteration 1019
# External iteration 1020
# External iteration 1021
# External iteration 1022
# External iteration 1023
# External iteration 1024
# External iteration 1025
# External iteration 1026
# External iteration 1027
# External iteration 1028
# External iteration 1029
# External iteration 1030
# External iteration 1031
# External iteration 1032
# External iteration 1033
# External iteration 1034
# External iteration 1035
# External iteration 1036
# External iteration 1037
# External iteration 1038
# External iteration 1039
# External iteration 1040
# External iteration 1041
# External iteration 1042
# External iteration 1043
# External iteration 1044
# External iteration 1045
# External iteration 1046
# External iteration 1047
# External iteration 1048
# External iteration 1049
# External iteration 1050
# External iteration 1051
# External iteration 1052
# External iteration 1053
# External iteration 1054
# External iteration 1055
# External iteration 1056
# External iteration 1057
# External iteration 1058
# External iteration 1059
# External iteration 1060
# External iteration 1061
# External iteration 1062
# External iteration 1063
# External iteration 1064
# External iteration 1065
# External iteration 1066
# External iteration 1067
# External iteration 1068
# External iteration 1069
# External iteration 1070
# External iteration 1071
# External iteration 1072
# External iteration 1073
# External iteration 1074
# External iteration 1075
# External iteration 1076
# External iteration 1077
# External iteration 1078
# External iteration 1079
# External iteration 1080
# External iteration 1081
# External iteration 1082
# External iteration 1083
# External iteration 1084
# External iteration 1085
# External iteration 1086
# External iteration 1087
# External iteration 1088
# External iteration 1089
# External iteration 1090
# External iteration 1091
# External iteration 1092
# External iteration 1093
# External iteration 1094
# External iteration 1095
# External iteration 1096
# External iteration 1097
# External iteration 1098
# External iteration 1099
# External iteration 1100
# External iteration 1101
# External iteration 1102
# External iteration 1103
# External iteration 1104
# External iteration 1105
# External iteration 1106
# External iteration 1107
# External iteration 1108
# External iteration 1109
# External iteration 1110
# External iteration 1111
# External iteration 1112
# External iteration 1113
# External iteration 1114
# External iteration 1115
# External iteration 1116
# External iteration 1117
# External iteration 1118
# External iteration 1119
# External iteration 1120
# External iteration 1121
# External iteration 1122
# External iteration 1123
# External iteration 1124
# External iteration 1125
# External iteration 1126
# External iteration 1127
# External iteration 1128
# External iteration 1129
# External iteration 1130
# External iteration 1131
# External iteration 1132
# External iteration 1133
# External iteration 1134
# External iteration 1135
# External iteration 1136
# External iteration 1137
# External iteration 1138
# External iteration 1139
# External iteration 1140
# External iteration 1141
# External iteration 1142
# External iteration 1143
# External iteration 1144
# External iteration 1145
# External iteration 1146
# External iteration 1147
# External iteration 1148
# External iteration 1149
# External iteration 1150
# External iteration 1151
# External iteration 1152
# External iteration 1153
# External iteration 1154
# External iteration 1155
# External iteration 1156
# External iteration 1157
# External iteration 1158
# External iteration 1159
# External iteration 1160
# External iteration 1161
# External iteration 1162
# External iteration 1163
# External iteration 1164
# External iteration 1165
# External iteration 1166
# External iteration 1167
# External iteration 1168
# External iteration 1169
# External iteration 1170
# External iteration 1171
# External iteration 1172
# External iteration 1173
# External iteration 1174
# External iteration 1175
# External iteration 1176
# External iteration 1177
# External iteration 1178
# External iteration 1179
# External iteration 1180
# External iteration 1181
# External iteration 1182
# External iteration 1183
# External iteration 1184
# External iteration 1185
# External iteration 1186
# External iteration 1187
# External iteration 1188
# External iteration 1189
# External iteration 1190
# External iteration 1191
# External iteration 1192
# External iteration 1193
# External iteration 1194
# External iteration 1195
# External iteration 1196
# External iteration 1197
# External iteration 1198
# External iteration 1199
# External iteration 1200
# External iteration 1201
# External iteration 1202
# External iteration 1203
# External iteration 1204
# External iteration 1205
# External iteration 1206
# External iteration 1207
# External iteration 1208
# External iteration 1209
# External iteration 1210
# External iteration 1211
# External iteration 1212
# External iteration 1213
# External iteration 1214
# External iteration 1215
# External iteration 1216
# External iteration 1217
# External iteration 1218
# External iteration 1219
# External iteration 1220
# External iteration 1221
# External iteration 1222
# External iteration 1223
# External iteration 1224
# External iteration 1225
# External iteration 1226
# External iteration 1227
# External iteration 1228
# External iteration 1229
# External iteration 1230
# External iteration 1231
# External iteration 1232
# External iteration 1233
# External iteration 1234
# External iteration 1235
# External iteration 1236
# External iteration 1237
# External iteration 1238
# External iteration 1239
# External iteration 1240
# External iteration 1241
# External iteration 1242
# External iteration 1243
# External iteration 1244
# External iteration 1245
# External iteration 1246
# External iteration 1247
# External iteration 1248
# External iteration 1249
# External iteration 1250
# External iteration 1251
# External iteration 1252
# External iteration 1253
# External iteration 1254
# External iteration 1255
# External iteration 1256
# External iteration 1257
# External iteration 1258
# External iteration 1259
# External iteration 1260
# External iteration 1261
# External iteration 1262
# External iteration 1263
# External iteration 1264
# External iteration 1265
# External iteration 1266
# External iteration 1267
# External iteration 1268
# External iteration 1269
# External iteration 1270
# External iteration 1271
# External iteration 1272
# External iteration 1273
# External iteration 1274
# External iteration 1275
# External iteration 1276
# External iteration 1277
# External iteration 1278
# External iteration 1279
# External iteration 1280
# External iteration 1281
# External iteration 1282
# External iteration 1283
# External iteration 1284
# External iteration 1285
# External iteration 1286
# External iteration 1287
# External iteration 1288
# External iteration 1289
# External iteration 1290
# External iteration 1291
# External iteration 1292
# External iteration 1293
# External iteration 1294
# External iteration 1295
# External iteration 1296
# External iteration 1297
# External iteration 1298
# External iteration 1299
# External iteration 1300
# External iteration 1301
# External iteration 1302
# External iteration 1303
# External iteration 1304
# External iteration 1305
# External iteration 1306
# External iteration 1307
# External iteration 1308
# External iteration 1309
# External iteration 1310
# External iteration 1311
# External iteration 1312
# External iteration 1313
# External iteration 1314
# External iteration 1315
# External iteration 1316
# External iteration 1317
# External iteration 1318
# External iteration 1319
# External iteration 1320
# External iteration 1321
# External iteration 1322
# External iteration 1323
# External iteration 1324
# External iteration 1325
# External iteration 1326
# External iteration 1327
# External iteration 1328
# External iteration 1329
# External iteration 1330
# External iteration 1331
# External iteration 1332
# External iteration 1333
# External iteration 1334
# External iteration 1335
# External iteration 1336
# External iteration 1337
# External iteration 1338
# External iteration 1339
# External iteration 1340
# External iteration 1341
# External iteration 1342
# External iteration 1343
# External iteration 1344
# External iteration 1345
# External iteration 1346
# External iteration 1347
# External iteration 1348
# External iteration 1349
# External iteration 1350
# External iteration 1351
# External iteration 1352
# External iteration 1353
# External iteration 1354
# External iteration 1355
# External iteration 1356
# External iteration 1357
# External iteration 1358
# External iteration 1359
# External iteration 1360
# External iteration 1361
# External iteration 1362
# External iteration 1363
# External iteration 1364
# External iteration 1365
# External iteration 1366
# External iteration 1367
# External iteration 1368
# External iteration 1369
# External iteration 1370
# External iteration 1371
# External iteration 1372
# External iteration 1373
# External iteration 1374
# External iteration 1375
# External iteration 1376
# External iteration 1377
# External iteration 1378
# External iteration 1379
# External iteration 1380
# External iteration 1381
# External iteration 1382
# External iteration 1383
# External iteration 1384
# External iteration 1385
# External iteration 1386
# External iteration 1387
# External iteration 1388
# External iteration 1389
# External iteration 1390
# External iteration 1391
# External iteration 1392
# External iteration 1393
# External iteration 1394
# External iteration 1395
# External iteration 1396
# External iteration 1397
# External iteration 1398
# External iteration 1399
# External iteration 1400
# External iteration 1401
# External iteration 1402
# External iteration 1403
# External iteration 1404
# External iteration 1405
# External iteration 1406
# External iteration 1407
# External iteration 1408
# External iteration 1409
# External iteration 1410
# External iteration 1411
# External iteration 1412
# External iteration 1413
# External iteration 1414
# External iteration 1415
# External iteration 1416
# External iteration 1417
# External iteration 1418
# External iteration 1419
# External iteration 1420
# External iteration 1421
# External iteration 1422
# External iteration 1423
# External iteration 1424
# External iteration 1425
# External iteration 1426
# External iteration 1427
# External iteration 1428
# External iteration 1429
# External iteration 1430
# External iteration 1431
# External iteration 1432
# External iteration 1433
# External iteration 1434
# External iteration 1435
# External iteration 1436
# External iteration 1437
# External iteration 1438
# External iteration 1439
# External iteration 1440
# External iteration 1441
# External iteration 1442
# External iteration 1443
# External iteration 1444
# External iteration 1445
# External iteration 1446
# External iteration 1447
# External iteration 1448
# External iteration 1449
# External iteration 1450
# External iteration 1451
# External iteration 1452
# External iteration 1453
# External iteration 1454
# External iteration 1455
# External iteration 1456
# External iteration 1457
# External iteration 1458
# External iteration 1459
# External iteration 1460
# External iteration 1461
# External iteration 1462
# External iteration 1463
# External iteration 1464
# External iteration 1465
# External iteration 1466
# External iteration 1467
# External iteration 1468
# External iteration 1469
# External iteration 1470
# External iteration 1471
# External iteration 1472
# External iteration 1473
# External iteration 1474
# External iteration 1475
# External iteration 1476
# External iteration 1477
# External iteration 1478
# External iteration 1479
# External iteration 1480
# External iteration 1481
# External iteration 1482
# External iteration 1483
# External iteration 1484
# External iteration 1485
# External iteration 1486
# External iteration 1487
# External iteration 1488
# External iteration 1489
# External iteration 1490
# External iteration 1491
# External iteration 1492
# External iteration 1493
# External iteration 1494
# External iteration 1495
# External iteration 1496
# External iteration 1497
# External iteration 1498
# External iteration 1499
# External iteration 1500
# External iteration 1501
# External iteration 1502
# External iteration 1503
# External iteration 1504
# External iteration 1505
# External iteration 1506
# External iteration 1507
# External iteration 1508
# External iteration 1509
# External iteration 1510
# External iteration 1511
# External iteration 1512
# External iteration 1513
# External iteration 1514
# External iteration 1515
# External iteration 1516
# External iteration 1517
# External iteration 1518
# External iteration 1519
# External iteration 1520
# External iteration 1521
# External iteration 1522
# External iteration 1523
# External iteration 1524
# External iteration 1525
# External iteration 1526
# External iteration 1527
# External iteration 1528
# External iteration 1529
# External iteration 1530
# External iteration 1531
# External iteration 1532
# External iteration 1533
# External iteration 1534
# External iteration 1535
# External iteration 1536
# External iteration 1537
# External iteration 1538
# External iteration 1539
# External iteration 1540
# External iteration 1541
# External iteration 1542
# External iteration 1543
# External iteration 1544
# External iteration 1545
# External iteration 1546
# External iteration 1547
# External iteration 1548
# External iteration 1549
# External iteration 1550
# External iteration 1551
# External iteration 1552
# External iteration 1553
# External iteration 1554
# External iteration 1555
# External iteration 1556
# External iteration 1557
# External iteration 1558
# External iteration 1559
# External iteration 1560
# External iteration 1561
# External iteration 1562
# External iteration 1563
# External iteration 1564
# External iteration 1565
# External iteration 1566
# External iteration 1567
# External iteration 1568
# External iteration 1569
# External iteration 1570
# External iteration 1571
# External iteration 1572
# External iteration 1573
# External iteration 1574
# External iteration 1575
# External iteration 1576
# External iteration 1577
# External iteration 1578
# External iteration 1579
# External iteration 1580
# External iteration 1581
# External iteration 1582
# External iteration 1583
# External iteration 1584
# External iteration 1585
# External iteration 1586
# External iteration 1587
# External iteration 1588
# External iteration 1589
# External iteration 1590
# External iteration 1591
# External iteration 1592
# External iteration 1593
# External iteration 1594
# External iteration 1595
# External iteration 1596
# External iteration 1597
# External iteration 1598
# External iteration 1599
# External iteration 1600
# External iteration 1601
# External iteration 1602
# External iteration 1603
# External iteration 1604
# External iteration 1605
# External iteration 1606
# External iteration 1607
# External iteration 1608
# External iteration 1609
# External iteration 1610
# External iteration 1611
# External iteration 1612
# External iteration 1613
# External iteration 1614
# External iteration 1615
# External iteration 1616
# External iteration 1617
# External iteration 1618
# External iteration 1619
# External iteration 1620
# External iteration 1621
# External iteration 1622
# External iteration 1623
# External iteration 1624
# External iteration 1625
# External iteration 1626
# External iteration 1627
# External iteration 1628
# External iteration 1629
# External iteration 1630
# External iteration 1631
# External iteration 1632
# External iteration 1633
# External iteration 1634
# External iteration 1635
# External iteration 1636
# External iteration 1637
# External iteration 1638
# External iteration 1639
# External iteration 1640
# External iteration 1641
# External iteration 1642
# External iteration 1643
# External iteration 1644
# External iteration 1645
# External iteration 1646
# External iteration 1647
# External iteration 1648
# External iteration 1649
# External iteration 1650
# External iteration 1651
# External iteration 1652
# External iteration 1653
# External iteration 1654
# External iteration 1655
# External iteration 1656
# External iteration 1657
# External iteration 1658
# External iteration 1659
# External iteration 1660
# External iteration 1661
# External iteration 1662
# External iteration 1663
# External iteration 1664
# External iteration 1665
# External iteration 1666
# External iteration 1667
# External iteration 1668
# External iteration 1669
# External iteration 1670
# External iteration 1671
# External iteration 1672
# External iteration 1673
# External iteration 1674
# External iteration 1675
# External iteration 1676
# External iteration 1677
# External iteration 1678
# External iteration 1679
# External iteration 1680
# External iteration 1681
# External iteration 1682
# External iteration 1683
# External iteration 1684
# External iteration 1685
# External iteration 1686
# External iteration 1687
# External iteration 1688
# External iteration 1689
# External iteration 1690
# External iteration 1691
# External iteration 1692
# External iteration 1693
# External iteration 1694
# External iteration 1695
# External iteration 1696
# External iteration 1697
# External iteration 1698
# External iteration 1699
# External iteration 1700
# External iteration 1701
# External iteration 1702
# External iteration 1703
# External iteration 1704
# External iteration 1705
# External iteration 1706
# External iteration 1707
# External iteration 1708
# External iteration 1709
# External iteration 1710
# External iteration 1711
# External iteration 1712
# External iteration 1713
# External iteration 1714
# External iteration 1715
# External iteration 1716
# External iteration 1717
# External iteration 1718
# External iteration 1719
# External iteration 1720
# External iteration 1721
# External iteration 1722
# External iteration 1723
# External iteration 1724
# External iteration 1725
# External iteration 1726
# External iteration 1727
# External iteration 1728
# External iteration 1729
# External iteration 1730
# External iteration 1731
# External iteration 1732
# External iteration 1733
# External iteration 1734
# External iteration 1735
# External iteration 1736
# External iteration 1737
# External iteration 1738
# External iteration 1739
# External iteration 1740
# External iteration 1741
# External iteration 1742
# External iteration 1743
# External iteration 1744
# External iteration 1745
# External iteration 1746
# External iteration 1747
# External iteration 1748
# External iteration 1749
# External iteration 1750
# External iteration 1751
# External iteration 1752
# External iteration 1753
# External iteration 1754
# External iteration 1755
# External iteration 1756
# External iteration 1757
# External iteration 1758
# External iteration 1759
# External iteration 1760
# External iteration 1761
# External iteration 1762
# External iteration 1763
# External iteration 1764
# External iteration 1765
# External iteration 1766
# External iteration 1767
# External iteration 1768
# External iteration 1769
# External iteration 1770
# External iteration 1771
# External iteration 1772
# External iteration 1773
# External iteration 1774
# External iteration 1775
# External iteration 1776
# External iteration 1777
# External iteration 1778
# External iteration 1779
# External iteration 1780
# External iteration 1781
# External iteration 1782
# External iteration 1783
# External iteration 1784
# External iteration 1785
# External iteration 1786
# External iteration 1787
# External iteration 1788
# External iteration 1789
# External iteration 1790
# External iteration 1791
# External iteration 1792
# External iteration 1793
# External iteration 1794
# External iteration 1795
# External iteration 1796
# External iteration 1797
# External iteration 1798
# External iteration 1799
# External iteration 1800
# External iteration 1801
# External iteration 1802
# External iteration 1803
# External iteration 1804
# External iteration 1805
# External iteration 1806
# External iteration 1807
# External iteration 1808
# External iteration 1809
# External iteration 1810
# External iteration 1811
# External iteration 1812
# External iteration 1813
# External iteration 1814
# External iteration 1815
# External iteration 1816
# External iteration 1817
# External iteration 1818
# External iteration 1819
# External iteration 1820
# External iteration 1821
# External iteration 1822
# External iteration 1823
# External iteration 1824
# External iteration 1825
# External iteration 1826
# External iteration 1827
# External iteration 1828
# External iteration 1829
# External iteration 1830
# External iteration 1831
# External iteration 1832
# External iteration 1833
# External iteration 1834
# External iteration 1835
# External iteration 1836
# External iteration 1837
# External iteration 1838
# External iteration 1839
# External iteration 1840
# External iteration 1841
# External iteration 1842
# External iteration 1843
# External iteration 1844
# External iteration 1845
# External iteration 1846
# External iteration 1847
# External iteration 1848
# External iteration 1849
# External iteration 1850
# External iteration 1851
# External iteration 1852
# External iteration 1853
# External iteration 1854
# External iteration 1855
# External iteration 1856
# External iteration 1857
# External iteration 1858
# External iteration 1859
# External iteration 1860
# External iteration 1861
# External iteration 1862
# External iteration 1863
# External iteration 1864
# External iteration 1865
# External iteration 1866
# External iteration 1867
# External iteration 1868
# External iteration 1869
# External iteration 1870
# External iteration 1871
# External iteration 1872
# External iteration 1873
# External iteration 1874
# External iteration 1875
# External iteration 1876
# External iteration 1877
# External iteration 1878
# External iteration 1879
# External iteration 1880
# External iteration 1881
# External iteration 1882
# External iteration 1883
# External iteration 1884
# External iteration 1885
# External iteration 1886
# External iteration 1887
# External iteration 1888
# External iteration 1889
# External iteration 1890
# External iteration 1891
# External iteration 1892
# External iteration 1893
# External iteration 1894
# External iteration 1895
# External iteration 1896
# External iteration 1897
# External iteration 1898
# External iteration 1899
# External iteration 1900
# External iteration 1901
# External iteration 1902
# External iteration 1903
# External iteration 1904
# External iteration 1905
# External iteration 1906
# External iteration 1907
# External iteration 1908
# External iteration 1909
# External iteration 1910
# External iteration 1911
# External iteration 1912
# External iteration 1913
# External iteration 1914
# External iteration 1915
# External iteration 1916
# External iteration 1917
# External iteration 1918
# External iteration 1919
# External iteration 1920
# External iteration 1921
# External iteration 1922
# External iteration 1923
# External iteration 1924
# External iteration 1925
# External iteration 1926
# External iteration 1927
# External iteration 1928
# External iteration 1929
# External iteration 1930
# External iteration 1931
# External iteration 1932
# External iteration 1933
# External iteration 1934
# External iteration 1935
# External iteration 1936
# External iteration 1937
# External iteration 1938
# External iteration 1939
# External iteration 1940
# External iteration 1941
# External iteration 1942
# External iteration 1943
# External iteration 1944
# External iteration 1945
# External iteration 1946
# External iteration 1947
# External iteration 1948
# External iteration 1949
# External iteration 1950
# External iteration 1951
# External iteration 1952
# External iteration 1953
# External iteration 1954
# External iteration 1955
# External iteration 1956
# External iteration 1957
# External iteration 1958
# External iteration 1959
# External iteration 1960
# External iteration 1961
# External iteration 1962
# External iteration 1963
# External iteration 1964
# External iteration 1965
# External iteration 1966
# External iteration 1967
# External iteration 1968
# External iteration 1969
# External iteration 1970
# External iteration 1971
# External iteration 1972
# External iteration 1973
# External iteration 1974
# External iteration 1975
# External iteration 1976
# External iteration 1977
# External iteration 1978
# External iteration 1979
# External iteration 1980
# External iteration 1981
# External iteration 1982
# External iteration 1983
# External iteration 1984
# External iteration 1985
# External iteration 1986
# External iteration 1987
# External iteration 1988
# External iteration 1989
# External iteration 1990
# External iteration 1991
# External iteration 1992
# External iteration 1993
# External iteration 1994
# External iteration 1995
# External iteration 1996
# External iteration 1997
# External iteration 1998
# External iteration 1999
# External iteration 2000
# External iteration 2001
# External iteration 2002
# External iteration 2003
# External iteration 2004
# External iteration 2005
# External iteration 2006
# External iteration 2007
# External iteration 2008
# External iteration 2009
# External iteration 2010
# External iteration 2011
# External iteration 2012
# External iteration 2013
# External iteration 2014
# External iteration 2015
# External iteration 2016
# External iteration 2017
# External iteration 2018
# External iteration 2019
# External iteration 2020
# External iteration 2021
# External iteration 2022
# External iteration 2023
# External iteration 2024
# External iteration 2025
# External iteration 2026
# External iteration 2027
# External iteration 2028
# External iteration 2029
# External iteration 2030
# External iteration 2031
# External iteration 2032
# External iteration 2033
# External iteration 2034
# External iteration 2035
# External iteration 2036
# External iteration 2037
# External iteration 2038
# External iteration 2039
# External iteration 2040
# External iteration 2041
# External iteration 2042
# External iteration 2043
# External iteration 2044
# External iteration 2045
# ...
# External iteration 5915
# External iteration 5916
# External iteration 5917
# External iteration 5918
# External iteration 5919
# External iteration 5920
# External iteration 5921
# External iteration 5922
# External iteration 5923
# External iteration 5924
# External iteration 5925
# External iteration 5926
# External iteration 5927
# External iteration 5928
# External iteration 5929
# External iteration 5930
# External iteration 5931
# External iteration 5932
# External iteration 5933
# External iteration 5934
# External iteration 5935
# External iteration 5936
# External iteration 5937
# External iteration 5938
# External iteration 5939
# External iteration 5940
# External iteration 5941
# External iteration 5942
# External iteration 5943
# External iteration 5944
# External iteration 5945
# External iteration 5946
# External iteration 5947
# External iteration 5948
# External iteration 5949
# External iteration 5950
# External iteration 5951
# External iteration 5952
# External iteration 5953
# External iteration 5954
# External iteration 5955
# External iteration 5956
# External iteration 5957
# External iteration 5958
# External iteration 5959
# External iteration 5960
# External iteration 5961
# External iteration 5962
# External iteration 5963
# External iteration 5964
# External iteration 5965
# External iteration 5966
# External iteration 5967
# External iteration 5968
# External iteration 5969
# External iteration 5970
# External iteration 5971
# External iteration 5972
# External iteration 5973
# External iteration 5974
# External iteration 5975
# External iteration 5976
# External iteration 5977
# External iteration 5978
# External iteration 5979
# External iteration 5980
# External iteration 5981
# External iteration 5982
# External iteration 5983
# External iteration 5984
# External iteration 5985
# External iteration 5986
# External iteration 5987
# External iteration 5988
# External iteration 5989
# External iteration 5990
# External iteration 5991
# External iteration 5992
# External iteration 5993
# External iteration 5994
# External iteration 5995
# External iteration 5996
# External iteration 5997
# External iteration 5998
# External iteration 5999
# External iteration 6000
# External iteration 6001
# External iteration 6002
# External iteration 6003
# External iteration 6004
# External iteration 6005
# External iteration 6006
# External iteration 6007
# External iteration 6008
# External iteration 6009
# External iteration 6010
# External iteration 6011
# External iteration 6012
# External iteration 6013
# External iteration 6014
# External iteration 6015
# External iteration 6016
# External iteration 6017
# External iteration 6018
# External iteration 6019
# External iteration 6020
# External iteration 6021
# External iteration 6022
# External iteration 6023
# External iteration 6024
# External iteration 6025
# External iteration 6026
# External iteration 6027
# External iteration 6028
# External iteration 6029
# External iteration 6030
# External iteration 6031
# External iteration 6032
# External iteration 6033
# External iteration 6034
# External iteration 6035
# External iteration 6036
# External iteration 6037
# External iteration 6038
# External iteration 6039
# External iteration 6040
# External iteration 6041
# External iteration 6042
# External iteration 6043
# External iteration 6044
# External iteration 6045
# External iteration 6046
# External iteration 6047
# External iteration 6048
# External iteration 6049
# External iteration 6050
# External iteration 6051
# External iteration 6052
# External iteration 6053
# External iteration 6054
# External iteration 6055
# External iteration 6056
# External iteration 6057
# External iteration 6058
# External iteration 6059
# External iteration 6060
# External iteration 6061
# External iteration 6062
# External iteration 6063
# External iteration 6064
# External iteration 6065
# External iteration 6066
# External iteration 6067
# External iteration 6068
# External iteration 6069
# External iteration 6070
# External iteration 6071
# External iteration 6072
# External iteration 6073
# External iteration 6074
# External iteration 6075
# External iteration 6076
# External iteration 6077
# External iteration 6078
# External iteration 6079
# External iteration 6080
# External iteration 6081
# External iteration 6082
# External iteration 6083
# External iteration 6084
# External iteration 6085
# External iteration 6086
# External iteration 6087
# External iteration 6088
# External iteration 6089
# External iteration 6090
# External iteration 6091
# External iteration 6092
# External iteration 6093
# External iteration 6094
# External iteration 6095
# External iteration 6096
# External iteration 6097
# External iteration 6098
# External iteration 6099
# External iteration 6100
# External iteration 6101
# External iteration 6102
# External iteration 6103
# External iteration 6104
# External iteration 6105
# External iteration 6106
# External iteration 6107
# External iteration 6108
# External iteration 6109
# External iteration 6110
# External iteration 6111
# External iteration 6112
# External iteration 6113
# External iteration 6114
# External iteration 6115
# External iteration 6116
# External iteration 6117
# External iteration 6118
# External iteration 6119
# External iteration 6120
# External iteration 6121
# External iteration 6122
# External iteration 6123
# External iteration 6124
# External iteration 6125
# External iteration 6126
# External iteration 6127
# External iteration 6128
# External iteration 6129
# External iteration 6130
# External iteration 6131
# External iteration 6132
# External iteration 6133
# External iteration 6134
# External iteration 6135
# External iteration 6136
# External iteration 6137
# External iteration 6138
# External iteration 6139
# External iteration 6140
# External iteration 6141
# External iteration 6142
# External iteration 6143
# External iteration 6144
# External iteration 6145
# External iteration 6146
# External iteration 6147
# External iteration 6148
# External iteration 6149
# External iteration 6150
# External iteration 6151
# External iteration 6152
# External iteration 6153
# External iteration 6154
# External iteration 6155
# External iteration 6156
# External iteration 6157
# External iteration 6158
# External iteration 6159
# External iteration 6160
# External iteration 6161
# External iteration 6162
# External iteration 6163
# External iteration 6164
# External iteration 6165
# External iteration 6166
# External iteration 6167
# External iteration 6168
# External iteration 6169
# External iteration 6170
# External iteration 6171
# External iteration 6172
# External iteration 6173
# External iteration 6174
# External iteration 6175
# External iteration 6176
# External iteration 6177
# External iteration 6178
# External iteration 6179
# External iteration 6180
# External iteration 6181
# External iteration 6182
# External iteration 6183
# External iteration 6184
# External iteration 6185
# External iteration 6186
# External iteration 6187
# External iteration 6188
# External iteration 6189
# External iteration 6190
# External iteration 6191
# External iteration 6192
# External iteration 6193
# External iteration 6194
# External iteration 6195
# External iteration 6196
# External iteration 6197
# External iteration 6198
# External iteration 6199
# External iteration 6200
# External iteration 6201
# External iteration 6202
# External iteration 6203
# External iteration 6204
# External iteration 6205
# External iteration 6206
# External iteration 6207
# External iteration 6208
# External iteration 6209
# External iteration 6210
# External iteration 6211
# External iteration 6212
# External iteration 6213
# External iteration 6214
# External iteration 6215
# External iteration 6216
# External iteration 6217
# External iteration 6218
# External iteration 6219
# External iteration 6220
# External iteration 6221
# External iteration 6222
# External iteration 6223
# External iteration 6224
# External iteration 6225
# External iteration 6226
# External iteration 6227
# External iteration 6228
# External iteration 6229
# External iteration 6230
# External iteration 6231
# External iteration 6232
# External iteration 6233
# External iteration 6234
# External iteration 6235
# External iteration 6236
# External iteration 6237
# External iteration 6238
# External iteration 6239
# External iteration 6240
# External iteration 6241
# External iteration 6242
# External iteration 6243
# External iteration 6244
# External iteration 6245
# External iteration 6246
# External iteration 6247
# External iteration 6248
# External iteration 6249
# External iteration 6250
# External iteration 6251
# External iteration 6252
# External iteration 6253
# External iteration 6254
# External iteration 6255
# External iteration 6256
# External iteration 6257
# External iteration 6258
# External iteration 6259
# External iteration 6260
# External iteration 6261
# External iteration 6262
# External iteration 6263
# External iteration 6264
# External iteration 6265
# External iteration 6266
# External iteration 6267
# External iteration 6268
# External iteration 6269
# External iteration 6270
# External iteration 6271
# External iteration 6272
# External iteration 6273
# External iteration 6274
# External iteration 6275
# External iteration 6276
# External iteration 6277
# External iteration 6278
# External iteration 6279
# External iteration 6280
# External iteration 6281
# External iteration 6282
# External iteration 6283
# External iteration 6284
# External iteration 6285
# External iteration 6286
# External iteration 6287
# External iteration 6288
# External iteration 6289
# External iteration 6290
# External iteration 6291
# External iteration 6292
# External iteration 6293
# External iteration 6294
# External iteration 6295
# External iteration 6296
# External iteration 6297
# External iteration 6298
# External iteration 6299
# External iteration 6300
# External iteration 6301
# External iteration 6302
# External iteration 6303
# External iteration 6304
# External iteration 6305
# External iteration 6306
# External iteration 6307
# External iteration 6308
# External iteration 6309
# External iteration 6310
# External iteration 6311
# External iteration 6312
# External iteration 6313
# External iteration 6314
# External iteration 6315
# External iteration 6316
# External iteration 6317
# External iteration 6318
# External iteration 6319
# External iteration 6320
# External iteration 6321
# External iteration 6322
# External iteration 6323
# External iteration 6324
# External iteration 6325
# External iteration 6326
# External iteration 6327
# External iteration 6328
# External iteration 6329
# External iteration 6330
# External iteration 6331
# External iteration 6332
# External iteration 6333
# External iteration 6334
# External iteration 6335
# External iteration 6336
# External iteration 6337
# External iteration 6338
# External iteration 6339
# External iteration 6340
# External iteration 6341
# External iteration 6342
# External iteration 6343
# External iteration 6344
# External iteration 6345
# External iteration 6346
# External iteration 6347
# External iteration 6348
# External iteration 6349
# External iteration 6350
# External iteration 6351
# External iteration 6352
# External iteration 6353
# External iteration 6354
# External iteration 6355
# External iteration 6356
# External iteration 6357
# External iteration 6358
# External iteration 6359
# External iteration 6360
# External iteration 6361
# External iteration 6362
# External iteration 6363
# External iteration 6364
# External iteration 6365
# External iteration 6366
# External iteration 6367
# External iteration 6368
# External iteration 6369
# External iteration 6370
# External iteration 6371
# External iteration 6372
# External iteration 6373
# External iteration 6374
# External iteration 6375
# External iteration 6376
# External iteration 6377
# External iteration 6378
# External iteration 6379
# External iteration 6380
# External iteration 6381
# External iteration 6382
# External iteration 6383
# External iteration 6384
# External iteration 6385
# External iteration 6386
# External iteration 6387
# External iteration 6388
# External iteration 6389
# External iteration 6390
# External iteration 6391
# External iteration 6392
# External iteration 6393
# External iteration 6394
# External iteration 6395
# External iteration 6396
# External iteration 6397
# External iteration 6398
# External iteration 6399
# External iteration 6400
# External iteration 6401
# External iteration 6402
# External iteration 6403
# External iteration 6404
# External iteration 6405
# External iteration 6406
# External iteration 6407
# External iteration 6408
# External iteration 6409
# External iteration 6410
# External iteration 6411
# External iteration 6412
# External iteration 6413
# External iteration 6414
# External iteration 6415
# External iteration 6416
# External iteration 6417
# External iteration 6418
# External iteration 6419
# External iteration 6420
# External iteration 6421
# External iteration 6422
# External iteration 6423
# External iteration 6424
# External iteration 6425
# External iteration 6426
# External iteration 6427
# External iteration 6428
# External iteration 6429
# External iteration 6430
# External iteration 6431
# External iteration 6432
# External iteration 6433
# External iteration 6434
# External iteration 6435
# External iteration 6436
# External iteration 6437
# External iteration 6438
# External iteration 6439
# External iteration 6440
# External iteration 6441
# External iteration 6442
# External iteration 6443
# External iteration 6444
# External iteration 6445
# External iteration 6446
# External iteration 6447
# External iteration 6448
# External iteration 6449
# External iteration 6450
# External iteration 6451
# External iteration 6452
# External iteration 6453
# External iteration 6454
# External iteration 6455
# External iteration 6456
# External iteration 6457
# External iteration 6458
# External iteration 6459
# External iteration 6460
# External iteration 6461
# External iteration 6462
# External iteration 6463
# External iteration 6464
# External iteration 6465
# External iteration 6466
# External iteration 6467
# External iteration 6468
# External iteration 6469
# External iteration 6470
# External iteration 6471
# External iteration 6472
# External iteration 6473
# External iteration 6474
# External iteration 6475
# External iteration 6476
# External iteration 6477
# External iteration 6478
# External iteration 6479
# External iteration 6480
# External iteration 6481
# External iteration 6482
# External iteration 6483
# External iteration 6484
# External iteration 6485
# External iteration 6486
# External iteration 6487
# External iteration 6488
# External iteration 6489
# External iteration 6490
# External iteration 6491
# External iteration 6492
# External iteration 6493
# External iteration 6494
# External iteration 6495
# External iteration 6496
# External iteration 6497
# External iteration 6498
# External iteration 6499
# External iteration 6500
# External iteration 6501
# External iteration 6502
# External iteration 6503
# External iteration 6504
# External iteration 6505
# External iteration 6506
# External iteration 6507
# External iteration 6508
# External iteration 6509
# External iteration 6510
# External iteration 6511
# External iteration 6512
# External iteration 6513
# External iteration 6514
# External iteration 6515
# External iteration 6516
# External iteration 6517
# External iteration 6518
# External iteration 6519
# External iteration 6520
# External iteration 6521
# External iteration 6522
# External iteration 6523
# External iteration 6524
# External iteration 6525
# External iteration 6526
# External iteration 6527
# External iteration 6528
# External iteration 6529
# External iteration 6530
# External iteration 6531
# External iteration 6532
# External iteration 6533
# External iteration 6534
# External iteration 6535
# External iteration 6536
# External iteration 6537
# External iteration 6538
# External iteration 6539
# External iteration 6540
# External iteration 6541
# External iteration 6542
# External iteration 6543
# External iteration 6544
# External iteration 6545
# External iteration 6546
# External iteration 6547
# External iteration 6548
# External iteration 6549
# External iteration 6550
# External iteration 6551
# External iteration 6552
# External iteration 6553
# External iteration 6554
# External iteration 6555
# External iteration 6556
# External iteration 6557
# External iteration 6558
# External iteration 6559
# External iteration 6560
# External iteration 6561
# External iteration 6562
# External iteration 6563
# External iteration 6564
# External iteration 6565
# External iteration 6566
# External iteration 6567
# External iteration 6568
# External iteration 6569
# External iteration 6570
# External iteration 6571
# External iteration 6572
# External iteration 6573
# External iteration 6574
# External iteration 6575
# External iteration 6576
# External iteration 6577
# External iteration 6578
# External iteration 6579
# External iteration 6580

# %% [markdown]
# #### Question 3 Answer Here
#
# The number of required iterations is this high simply because each iteration makes a miniscule change on the values that come before it. These gradual steps toward the decreasing error function eventually converge at the minimum. These gradual steps can also converge faster if both m and c are updated in the same loops.

# %% [markdown]
# ## Multiple Input Solution with Linear Algebra
#
# You've now seen how slow it can be to perform a coordinate ascent on a system. Another approach to solving the system (which is not always possible, particularly in *non-linear* systems) is to go direct to the minimum. To do this we need to introduce *linear algebra*. We will represent all our errors and functions in the form of linear algebra.
#
# As we mentioned above, linear algebra is just a shorthand for performing lots of multiplications and additions simultaneously. What does it have to do with our system then? Well the first thing to note is that the linear function we were trying to fit has the following form:
# $$
# f(x) = mx + c
# $$
# the classical form for a straight line. From a linear algebraic perspective we are looking for multiplications and additions. We are also looking to separate our parameters from our data. The data is the *givens* remember, in French the word is données literally translated means *givens* that's great, because we don't need to change the data, what we need to change are the parameters (or variables) of the model. In this function the data comes in through $x$, and the parameters are $m$ and $c$.
#
# What we'd like to create is a vector of parameters and a vector of data. Then we could represent the system with vectors that represent the data, and vectors that represent the parameters.
#
# We look to turn the multiplications and additions into a linear algebraic form, we have one multiplication ($m\times c$) and one addition ($mx + c$). But we can turn this into a inner product by writing it in the following way,
# $$
# f(x) = m \times x + c \times 1,
# $$
# in other words we've extracted the unit value, from the offset, $c$. We can think of this unit value like an extra item of data, because it is always given to us, and it is always set to 1 (unlike regular data, which is likely to vary!). We can therefore write each input data location, $\mathbf{x}$, as a vector
# $$
# \mathbf{x} = \begin{bmatrix} 1\\ x\end{bmatrix}.
# $$
#
# Now we choose to also turn our parameters into a vector. The parameter vector will be defined to contain
# $$
# \mathbf{w} = \begin{bmatrix} c \\ m\end{bmatrix}
# $$
# because if we now take the inner product between these to vectors we recover
# $$
# \mathbf{x}\cdot\mathbf{w} = 1 \times c + x \times m = mx + c
# $$
# In `numpy` we can define this vector as follows

# %%
# define the vector w
w = np.zeros(shape=(2, 1))
w[0] = m
w[1] = c

# %% [markdown]
# This gives us the equivalence between original operation and an operation in vector space. Whilst the notation here isn't a lot shorter, the beauty is that we will be able to add as many features as we like and still keep the same representation. In general, we are now moving to a system where each of our predictions is given by an inner product. When we want to represent a linear product in linear algebra, we tend to do it with the transpose operation, so since we have $\mathbf{a}\cdot\mathbf{b} = \mathbf{a}^\top\mathbf{b}$ we can write
# $$
# f(\mathbf{x}_i) = \mathbf{x}_i^\top\mathbf{w}.
# $$
# Where we've assumed that each data point, $\mathbf{x}_i$, is now written by appending a 1 onto the original vector
# $$
# \mathbf{x}_i =
# \begin{bmatrix}
# 1 \\
# x_i
# \end{bmatrix}
# $$
#
# ## Design Matrix
#
# We can do this for the entire data set to form a [*design matrix*](http://en.wikipedia.org/wiki/Design_matrix) $\mathbf{X}$,
#
# $$\mathbf{X} = \begin{bmatrix}
# \mathbf{x}_1^\top \\\
# \mathbf{x}_2^\top \\\
# \vdots \\\
# \mathbf{x}_n^\top
# \end{bmatrix} = \begin{bmatrix}
# 1 & x_1 \\\
# 1 & x_2 \\\
# \vdots & \vdots \\\
# 1 & x_n
# \end{bmatrix},$$
#
# which in `numpy` can be done with the following commands:

# %%
X = np.hstack((np.ones_like(x), x))
print(X)
# Out:
# [[1.000e+00 1.896e+03]
#  [1.000e+00 1.900e+03]
#  [1.000e+00 1.904e+03]
#  [1.000e+00 1.908e+03]
#  [1.000e+00 1.912e+03]
#  [1.000e+00 1.920e+03]
#  [1.000e+00 1.924e+03]
#  [1.000e+00 1.928e+03]
#  [1.000e+00 1.932e+03]
#  [1.000e+00 1.936e+03]
#  [1.000e+00 1.948e+03]
#  [1.000e+00 1.952e+03]
#  [1.000e+00 1.956e+03]
#  [1.000e+00 1.960e+03]
#  [1.000e+00 1.964e+03]
#  [1.000e+00 1.968e+03]
#  [1.000e+00 1.972e+03]
#  [1.000e+00 1.976e+03]
#  [1.000e+00 1.980e+03]
#  [1.000e+00 1.984e+03]
#  [1.000e+00 1.988e+03]
#  [1.000e+00 1.992e+03]
#  [1.000e+00 1.996e+03]
#  [1.000e+00 2.000e+03]
#  [1.000e+00 2.004e+03]
#  [1.000e+00 2.008e+03]
#  [1.000e+00 2.012e+03]]

# %% [markdown]
# ### Writing the Objective with Linear Algebra
#
# When we think of the objective function, we can think of it as the errors where the error is defined in a similar way to what it was in Legendre's day $y_i - f(\mathbf{x}_i)$, in statistics these errors are also sometimes called [*residuals*](http://en.wikipedia.org/wiki/Errors_and_residuals_in_statistics). So we can think as the objective and the prediction function as two separate parts, first we have,
# $$
# E(\mathbf{w}) = \sum_{i=1}^n (y_i - f(\mathbf{x}_i; \mathbf{w}))^2,
# $$
# where we've made the function $f(\cdot)$'s dependence on the parameters $\mathbf{w}$ explicit in this equation. Then we have the definition of the function itself,
# $$
# f(\mathbf{x}_i; \mathbf{w}) = \mathbf{x}_i^\top \mathbf{w}.
# $$
# Let's look again at these two equations and see if we can identify any inner products. The first equation is a sum of squares, which is promising. Any sum of squares can be represented by an inner product,
# $$
# a = \sum_{i=1}^{k} b^2_i = \mathbf{b}^\top\mathbf{b},
# $$
# so if we wish to represent $E(\mathbf{w})$ in this way, all we need to do is convert the sum operator to an inner product. We can get a vector from that sum operator by placing both $y_i$ and $f(\mathbf{x}_i; \mathbf{w})$ into vectors, which we do by defining
# $$
# \mathbf{y} = \begin{bmatrix}y_1\\y_2\\ \vdots \\ y_n\end{bmatrix}
# $$
# and defining
# $$
# \mathbf{f}(\mathbf{X}; \mathbf{w}) = \begin{bmatrix}f(\mathbf{x}_1; \mathbf{w})\\f(\mathbf{x}_2; \mathbf{w})\\ \vdots \\ f(\mathbf{x}_n; \mathbf{w})\end{bmatrix}.
# $$
# The second of these is actually a vector-valued function. This term may appear intimidating, but the idea is straightforward. A vector valued function is simply a vector whose elements are themselves defined as *functions*, i.e. it is a vector of functions, rather than a vector of scalars. The idea is so straightforward, that we are going to ignore it for the moment, and barely use it in the derivation. But it will reappear later when we introduce *basis functions*. So we will, for the moment, ignore the dependence of $\mathbf{f}$ on $\mathbf{w}$ and $\mathbf{X}$ and simply summarise it by a vector of numbers
# $$
# \mathbf{f} = \begin{bmatrix}f_1\\f_2\\ \vdots \\ f_n\end{bmatrix}.
# $$
# This allows us to write our objective in the folowing, linear algebraic form,
# $$
# E(\mathbf{w}) = (\mathbf{y} - \mathbf{f})^\top(\mathbf{y} - \mathbf{f})
# $$
# from the rules of inner products.
#
# But what of our matrix $\mathbf{X}$ of input data? At this point, we need to dust off [*matrix-vector multiplication*](http://en.wikipedia.org/wiki/Matrix_multiplication). Matrix multiplication is simply a convenient way of performing many inner products together, and it's exactly what we need to summarise the operation
# $$
# f_i = \mathbf{x}_i^\top\mathbf{w}.
# $$
# This operation tells us that each element of the vector $\mathbf{f}$ (our vector valued function) is given by an inner product between $\mathbf{x}_i$ and $\mathbf{w}$. In other words it is a series of inner products. Let's look at the definition of matrix multiplication, it takes the form
# $$
# \mathbf{c} = \mathbf{B}\mathbf{a}
# $$
# where $\mathbf{c}$ might be a $k$ dimensional vector (which we can intepret as a $k\times 1$ dimensional matrix), and $\mathbf{B}$ is a $k\times k$ dimensional matrix and $\mathbf{a}$ is a $k$ dimensional vector ($k\times 1$ dimensional matrix).
#
# The result of this multiplication is of the form
# $$
# \begin{bmatrix}c_1\\c_2 \\ \vdots \\ a_k\end{bmatrix} =
# \begin{bmatrix} b_{1,1} & b_{1, 2} & \dots & b_{1, k} \\
# b_{2, 1} & b_{2, 2} & \dots & b_{2, k} \\
# \vdots & \vdots & \ddots & \vdots \\
# b_{k, 1} & b_{k, 2} & \dots & b_{k, k} \end{bmatrix} \begin{bmatrix}a_1\\a_2 \\ \vdots\\ c_k\end{bmatrix} = \begin{bmatrix} b_{1, 1}a_1 + b_{1, 2}a_2 + \dots + b_{1, k}a_k\\
# b_{2, 1}a_1 + b_{2, 2}a_2 + \dots + b_{2, k}a_k \\
# \vdots\\
# b_{k, 1}a_1 + b_{k, 2}a_2 + \dots + b_{k, k}a_k\end{bmatrix}
# $$
# so we see that each element of the result, $\mathbf{a}$ is simply the inner product between each *row* of $\mathbf{B}$ and the vector $\mathbf{c}$. Because we have defined each element of $\mathbf{f}$ to be given by the inner product between each *row* of the design matrix and the vector $\mathbf{w}$ we now can write the full operation in one matrix multiplication,
# $$
# \mathbf{f} = \mathbf{X}\mathbf{w}.
# $$

# %%
f = np.dot(X, w) # np.dot does matrix multiplication in python

# %% [markdown]
# Combining this result with our objective function,
# $$
# E(\mathbf{w}) = (\mathbf{y} - \mathbf{f})^\top(\mathbf{y} - \mathbf{f})
# $$
# we find we have defined the *model* with two equations. One equation tells us the form of our predictive function and how it depends on its parameters, the other tells us the form of our objective function.

# %%
resid = (y-f)
E = np.dot(resid.T, resid) # matrix multiplication on a single vector is equivalent to a dot product.
print("Error function is:", E)

# %% [markdown]
# ### Assignment Question 4
#
# The prediction for our movie recommender system had the form
# $$
# f_{i,j} = \mathbf{u}_i^\top \mathbf{v}_j
# $$
# and the objective function was then
# $$
# E = \sum_{i,j} s_{i,j}(y_{i,j} - f_{i, j})^2
# $$
# Try writing this down in matrix and vector form. How many of the terms can you do? For each variable and parameter carefully think about whether it should be represented as a matrix or vector. Do as many of the terms as you can. Use $\LaTeX$ to give your answers and give the *dimensions* of any matrices you create.
#
# *20 marks*

# %% [markdown]
# #### Question 4 Answer
#
# $$
# E = Tr[S\odot(Y-F)^\top (Y-F)]
# $$
#
# Where
#
# $$
# F=UV^\top
# $$
#
# Here,
#
# $$
# U = \begin{bmatrix}u_{1,1} & u_{1,2}\\u_{2,1} & u_{2,2}\\ \vdots & \vdots\\ u_{m,1} & u_{m,2}\end{bmatrix}
# $$
#
# $$
# V = \begin{bmatrix}v_{1,1} & v_{1,2}\\v_{2,1} & v_{2,2}\\ \vdots & \vdots\\ v_{n,1} & v_{n,2}\end{bmatrix}
# $$
#
# $$
# UV^\top = \begin{bmatrix}u_{1,1} & u_{1,2}\\u_{2,1} & u_{2,2}\\ \vdots & \vdots\\ u_{m,1} & u_{m,2}\end{bmatrix} \begin{bmatrix}v_{1,1} & v_{2,1} & \dots & v_{n,1}\\v_{1,2} & v_{2,2} & \dots & v_{n,2}\end{bmatrix} = \begin{bmatrix}u_{1,1}v_{1,1}+u_{1,2}v_{1,2} & u_{1,1}v_{2,1}+u_{1,2}v_{2,2} & \dots & u_{1,1}v_{n,1}+u_{1,2}v_{n,2}\\u_{2,1}v_{1,1}+u_{2,2}v_{1,2} & u_{2,1}v_{2,1}+u_{2,2}v_{2,2} & \dots & u_{2,1}v_{n,1}+u_{2,2}v_{n,2}\\\vdots & \vdots & \ddots & \vdots\\u_{m,1}v_{1,1}+u_{m,2}v_{1,2} & u_{m,1}v_{2,1}+u_{m,2}v_{2,2} & \dots & u_{m,1}v_{n,1}+u_{m,2}v_{n,2}\end{bmatrix}
# $$
#
# $$
# UV^\top = \begin{bmatrix}u_1^\top v_1 & u_1^\top v_2 & \dots & u_1^\top v_n \\ u_2^\top v_1 & u_2^\top v_2 & \dots & u_2^\top v_n \\ \vdots & \vdots & \ddots & \vdots \\  u_m^\top v_1 & u_m^\top v_2 & \dots & u_m^\top v_n\end{bmatrix} = \begin{bmatrix}f_{1,1} & f_{1,2} & \dots & f_{1,n}\\f_{2,1} & f_{2,2} & \dots & f_{2,n}\\\vdots & \vdots & \ddots & \vdots\\f_{m,1} & f_{m,2} & \dots & f_{m,n}\end{bmatrix} = F
# $$
#
# Here, the dimensions of the matrices are: U is (m,2), V is (n,2) thus f is (m,n).
#
# $$
# Y = \begin{bmatrix}y_{1,1} & y_{1,2} & \dots & y_{1,n}\\y_{2,1} & y_{2,2} & \dots & y_{2,n}\\\vdots & \vdots & \ddots & \vdots\\y_{m,1} & y_{m,2} & \dots & y_{m,n}\end{bmatrix}
# $$
#
# $$
# Y-F = \begin{bmatrix}y_{1,1}-f_{1,1} & y_{1,2}-f_{1,2} & \dots & y_{1,n}-f_{1,n}\\y_{2,1}-f_{2,1} & y_{2,2}-f_{2,2} & \dots & y_{2,n}-f_{2,n}\\\vdots & \vdots & \ddots & \vdots\\y_{m,1}-f_{m,1} & y_{m,2}-f_{m,2} & \dots & y_{m,n}-f_{m,n}\end{bmatrix}
# $$
#
# $$
# S = \begin{bmatrix}s_{1,1} & s_{1,2} & \dots & s_{1,n}\\s_{2,1} & s_{2,2} & \dots & s_{2,n}\\\vdots & \vdots & \ddots & \vdots\\s_{m,1} & s_{m,2} & \dots & s_{m,n}\end{bmatrix}
# $$
#
# And $\odot$ is a pointwise product of the two matrices
#
# $$
# S\odot (Y-F) = \begin{bmatrix}(y_{1,1}-f_{1,1})s_{1,1} & (y_{1,2}-f_{1,2})s_{1,2} & \dots & (y_{1,n}-f_{1,n})s_{1,n}\\(y_{2,1}-f_{2,1})s_{2,1} & (y_{2,2}-f_{2,2})s_{2,2} & \dots & (y_{2,n}-f_{2,n})s_{2,n}\\\vdots & \vdots & \ddots & \vdots\\(y_{m,1}-f_{m,1})s_{m,1} & (y_{m,2}-f_{m,2})s_{m,2} & \dots & (y_{m,n}-f_{m,n})s_{m,n}\end{bmatrix}
# $$
#
# Thus $E = Tr[(S\odot (Y-F))^\top(Y-F)]$, can be seen to be the summation we require
#
# $$
# (S\odot (Y-F))^\top(Y-F) = \begin{bmatrix}(y_{1,1}-f_{1,1})s_{1,1} & (y_{2,1}-f_{2,1})s_{2,1} & \dots & (y_{m,1}-f_{m,1})s_{m,1} \\ (y_{1,2}-f_{1,2})s_{1,2} & (y_{2,2}-f_{2,2})s_{2,2} & \dots & (y_{m,2}-f_{m,2})s_{m,2} \\ \vdots & \vdots & \ddots & \vdots \\ (y_{1,n}-f_{1,n})s_{1,n} & (y_{2,n}-f_{2,n})s_{2,n} & \dots & (y_{m,n}-f_{m,n})s_{m,n}\end{bmatrix} \begin{bmatrix}y_{1,1}-f_{1,1} & y_{1,2}-f_{1,2} & \dots & y_{1,n}-f_{1,n}\\y_{2,1}-f_{2,1} & y_{2,2}-f_{2,2} & \dots & y_{2,n}-f_{2,n}\\\vdots & \vdots & \ddots & \vdots\\y_{m,1}-f_{m,1} & y_{m,2}-f_{m,2} & \dots & y_{m,n}-f_{m,n}\end{bmatrix}
# $$
#
# $$
# (S\odot (Y-F))^\top(Y-F) = \begin{bmatrix}\sum_is_{i,1}(y_{i,1}-f_{i,1})^2 & \sum_is_{i,1}(y_{i,1}-f_{i,1})(y_{i,2}-f_{i,2}) & \dots & \sum_is_{i,1}(y_{i,1}-f_{i,1})(y_{i,n}-f_{i,n})) \\ \sum_is_{i,2}(y_{i,2}-f_{i,2})(y_{i,1}-f_{i,1}) & \sum_is_{i,2}(y_{i,2}-f_{i,2})^2 & \dots & \sum_is_{i,2}(y_{i,2}-f_{i,2})(y_{i,n}-f_{i,n})) \\ \vdots & \vdots & \ddots & \vdots \\ \sum_is_{i,n}(y_{i,n}-f_{i,n})(y_{i,1}-f_{i,1}) & \sum_is_{i,n}(y_{i,n}-f_{i,n})(y_{i,2}-f_{i,2}) & \dots & \sum_is_{i,n}(y_{i,n}-f_{i,n})^2)\end{bmatrix}
# $$
#
# $$
# Tr[(S\odot (Y-F))^\top(Y-F)] = \sum_j\sum_is_{i,j}(y_{i,j}-f_{i,j})^2=\sum_{i,j}s_{i,j}(y_{i,j}-f_{i,j})^2=E
# $$
#
# Here the dimensions of Y-F are (m,n), $S\odot Y-F$ are also (m,n), and for $(S\odot(Y-F))^\top(Y-F)$ is (n,n). As is evident, this last matrix is a square matrix of size n.

# %% [markdown]
# ## Objective Optimisation
#
# Our *model* has now been defined with two equations, the prediction function and the objective function. Next we will use multivariate calculus to define an *algorithm* to fit the model. The separation between model and algorithm is important and is often overlooked. Our model contains a function that shows how it will be used for prediction, and a function that describes the objective function we need to optimise to obtain a good set of parameters.
#
# The linear regression model we have described is still the same as the one we fitted above with a coordinate ascent algorithm. We have only played with the notation to obtain the same model in a matrix and vector notation. However, we will now fit this model with a different algorithm, one that is much faster. It is such a widely used algorithm that from the end user's perspective it doesn't even look like an algorithm, it just appears to be a single operation (or function). However, underneath the computer calls an algorithm to find the solution. Further, the algorithm we obtain is very widely used, and because of this it turns out to be highly optimised.
#
# Once again we are going to try and find the stationary points of our objective by finding the *stationary points*. However, the stationary points of a multivariate function, are a little bit more complext to find. Once again we need to find the point at which the derivative is zero, but now we need to use  *multivariate calculus* to find it. This involves learning a few additional rules of differentiation (that allow you to do the derivatives of a function with respect to  vector), but in the end it makes things quite a bit easier. We define vectorial derivatives as follows,
# $$
# \frac{\text{d}E(\mathbf{w})}{\text{d}\mathbf{w}} = \begin{bmatrix}\frac{\partial E(\mathbf{w})}{\partial w_1}\\\frac{\partial E(\mathbf{w})}{\partial w_2}\end{bmatrix}.
# $$
# where $\frac{\partial E(\mathbf{w})}{\partial w_1}$ is the [partial derivative](http://en.wikipedia.org/wiki/Partial_derivative) of the error function with respect to $w_1$.
#
# Differentiation through multiplications and additions is relatively straightforward, and since linear algebra is just multiplication and addition, then its rules of diffentiation are quite straightforward too, but slightly more complex than regular derivatives.
#
# ### Matrix Differentiation
#
# We will need two rules of differentiation. The first is diffentiation of an inner product. By remebering that the inner product is made up of multiplication and addition, we can hope that its derivative is quite straightforward, and so it proves to be. We can start by thinking about the definition of the inner product,
# $$
# \mathbf{a}^\top\mathbf{z} = \sum_{i} a_i z_i,
# $$
# which if we were to take the derivative with respect to $z_k$ would simply return the gradient of the one term in the sum for which the derivative was non zero, that of $a_k$, so we know that
# $$
# \frac{\text{d}}{\text{d}z_k} \mathbf{a}^\top \mathbf{z} = a_k
# $$
# and by our definition of multivariate derivatives we can simply stack all the partial derivatives of this form in a vector to obtain the result that
# $$
# \frac{\text{d}}{\text{d}\mathbf{z}} \mathbf{a}^\top \mathbf{z} = \mathbf{a}.
# $$
# The second rule that's required is differentiation of a 'matrix quadratic'. A scalar quadratic in $z$ with coefficient $c$ has the form $cz^2$. If $\mathbf{z}$ is a $k\times 1$ vector and $\mathbf{C}$ is a $k \times k$ *matrix* of coefficients then the matrix quadratic form is written as $\mathbf{z}^\top \mathbf{C}\mathbf{z}$, which is itself a *scalar* quantity, but it is a function of a *vector*.
#
# #### Matching Dimensions in Matrix Multiplications
#
# There's a trick for telling that it's a scalar result. When you are doing maths with matrices, it's always worth pausing to perform a quick sanity check on the dimensions. Matrix multplication only works when the dimensions match. To be precise, the 'inner' dimension of the matrix must match. What is the inner dimension. If we multiply two matrices $\mathbf{A}$ and $\mathbf{B}$, the first of which has $k$ rows and $\ell$ columns and the second of which has $p$ rows and $q$ columns, then we can check whether the multiplication works by writing the dimensionalities next to each other,
# $$
# \mathbf{A} \mathbf{B} \rightarrow (k \times \underbrace{\ell)(p}_\text{inner dimensions} \times q) \rightarrow (k\times q).
# $$
# The inner dimensions are the two inside dimensions, $\ell$ and $p$. The multiplication will only work if $\ell=p$. The result of the multiplication will then be a $k\times q$ matrix: this dimensionality comes from the 'outer dimensions'. Note that matrix multiplication is not [*commutative*](http://en.wikipedia.org/wiki/Commutative_property). And if you change the order of the multiplication,
# $$
# \mathbf{B} \mathbf{A} \rightarrow (\ell \times \underbrace{k)(q}_\text{inner dimensions} \times p) \rightarrow (\ell \times p).
# $$
# firstly it may no longer even work, because now the condition is that $k=q$, and secondly the result could be of a different dimensionality. An exception is if the matrices are square matrices (e.g. same number of rows as columns) and they are both *symmetric*. A symmetric matrix is one for which $\mathbf{A}=\mathbf{A}^\top$, or equivalently, $a_{i,j} = a_{j,i}$ for all $i$ and $j$.
#
# You will need to get used to working with matrices and vectors applying and developing new machine learning techniques. You should have come across them before, but you may not have used them as extensively as we will now do in this course. You should get used to using this trick to check your work and ensure you know what the dimension of an output matrix should be. For our matrix quadratic form, it turns out that we can see it as a special type of inner product.
# $$
# \mathbf{z}^\top\mathbf{C}\mathbf{z} \rightarrow (1\times \underbrace{k) (k}_\text{inner dimensions}\times k) (k\times 1) \rightarrow \mathbf{b}^\top\mathbf{z}
# $$
# where $\mathbf{b} = \mathbf{C}\mathbf{z}$ so therefore the result is a scalar,
# $$
# \mathbf{b}^\top\mathbf{z} \rightarrow (1\times \underbrace{k) (k}_\text{inner dimensions}\times 1) \rightarrow (1\times 1)
# $$
# where a $(1\times 1)$ matrix is recognised as a scalar.
#
# This implies that we should be able to differentiate this form, and indeed the rule for its differentiation is slightly more complex than the inner product, but still quite simple,
# $$
# \frac{\text{d}}{\text{d}\mathbf{z}} \mathbf{z}^\top\mathbf{C}\mathbf{z}= \mathbf{C}\mathbf{z} + \mathbf{C}^\top \mathbf{z}.
# $$
# Note that in the special case where $\mathbf{C}$ is symmetric then we have $\mathbf{C} = \mathbf{C}^\top$ and the derivative simplifies to
# $$
# \frac{\text{d}}{\text{d}\mathbf{z}} \mathbf{z}^\top\mathbf{C}\mathbf{z}= 2\mathbf{C}\mathbf{z}.
# $$
# ### Differentiating the Objective
#
# First, we need to compute the full objective by substituting our prediction function into the objective function to obtain the objective in terms of $\mathbf{w}$. Doing this we obtain
# $$
# E(\mathbf{w})= (\mathbf{y} - \mathbf{X}\mathbf{w})^\top (\mathbf{y} - \mathbf{X}\mathbf{w}).
# $$
# We now need to differentiate this *quadratic form* to find the minimum. We differentiate with respect to the *vector* $\mathbf{w}$. But before we do that, we'll expand the brackets in the quadratic form to obtain a series of scalar terms. The rules for bracket expansion across the vectors are similar to those for the scalar system giving,
# $$
# (\mathbf{a} - \mathbf{b})^\top (\mathbf{c} - \mathbf{d}) = \mathbf{a}^\top \mathbf{c} - \mathbf{a}^\top \mathbf{d} - \mathbf{b}^\top \mathbf{c} + \mathbf{b}^\top \mathbf{d}
# $$
# which substituting for $\mathbf{a} = \mathbf{c} = \mathbf{y}$ and $\mathbf{b}=\mathbf{d} = \mathbf{X}\mathbf{w}$ gives
# $$
# E(\mathbf{w})= \mathbf{y}^\top\mathbf{y} - 2\mathbf{y}^\top\mathbf{X}\mathbf{w} + \mathbf{w}^\top\mathbf{X}^\top\mathbf{X}\mathbf{w}
# $$
# where we used the fact that $\mathbf{y}^\top\mathbf{X}\mathbf{w}= \mathbf{w}^\top\mathbf{X}^\top\mathbf{y}$. Now we can use our rules of differentiation to compute the derivative of this form, which is,
# $$
# \frac{\text{d}}{\text{d}\mathbf{w}}E(\mathbf{w})=- 2\mathbf{X}^\top \mathbf{y} + 2\mathbf{X}^\top\mathbf{X}\mathbf{w},
# $$
# where we have exploited the fact that $\mathbf{X}^\top\mathbf{X}$ is symmetric to obtain this result.

# %% [markdown]
# ### Assignment Question 5
#
# Use the equivalence between our vector and our matrix formulations of linear regression, alongside our definition of vector derivates, to match the gradients we've computed directly for $\frac{\text{d}E(c, m)}{\text{d}c}$ and $\frac{\text{d}E(c, m)}{\text{d}m}$ to those for $\frac{\text{d}E(\mathbf{w})}{\text{d}\mathbf{w}}$.
#
# *20 marks*

# %% [markdown]
# #### Question 5 Answer
#
# Given the following 2 definitions
#
# $$
# \frac{\text{d}E(m,c)}{\text{d}c} = -\sum_{i=1}^n 2(y_i-mx_i-c).
# $$
#
# $$
# \frac{\text{d}E(m,c)}{\text{d}m} = -\sum_{i=1}^n 2x_i(y_i-mx_i-c)
# $$
#
# We calculate
#
# $$
# \frac{\text{d}}{\text{d}\mathbf{w}}E(\mathbf{w})=- 2\mathbf{X}^\top \mathbf{y} + 2\mathbf{X}^\top\mathbf{X}\mathbf{w}
# $$
#
# $$
# \mathbf{X} = \begin{bmatrix}1 & x_1\\1 & x_2\\\vdots & \vdots\\1 & x_n\end{bmatrix}
# $$
#
# $$
# \mathbf{X}^\top \mathbf{y} = \begin{bmatrix}1 & 1 & \dots & 1\\x_1 & x_2 & \dots &x_n\end{bmatrix} \begin{bmatrix}y_1 \\ y_2 \\ \dots \\ y_n\end{bmatrix} = \begin{bmatrix}\sum_iy_i\\\sum_ix_iy_i\end{bmatrix}
# $$
#
# $$
# \mathbf{X} \mathbf{w} = \begin{bmatrix}1 & x_1 \\1 & x_2 \\ \vdots & \vdots \\1 & x_n\end{bmatrix} \begin{bmatrix}c \\ m\end{bmatrix} = \begin{bmatrix}mx_1+c \\ mx_2+c \\ \vdots \\ mx_n+c\end{bmatrix}
# $$
#
# $$
# \mathbf{X}^\top\mathbf{X} \mathbf{w} = \begin{bmatrix}1 & 1 & \dots & 1\\ x_1 & x_2 & \dots & x_n\end{bmatrix} \begin{bmatrix}mx_1+c \\ mx_2+c \\ \vdots \\ mx_n+c\end{bmatrix} = \begin{bmatrix}\sum_imx_i+c \\ \sum_imx_i^2+cx_i\end{bmatrix}
# $$
#
# $$
# \mathbf{X}^\top\mathbf{Y}-\mathbf{X}^\top\mathbf{X} \mathbf{w} = \begin{bmatrix}\sum_iy_i\\\sum_ix_iy_i\end{bmatrix}-\begin{bmatrix}\sum_imx_i+c \\ \sum_imx_i^2+cx_i\end{bmatrix} = \begin{bmatrix}\sum_iy-mx_i-c \\ \sum_ix_iy_i-mx_i^2-cx_i\end{bmatrix}
# $$
#
# $$
# \frac{\text{d}}{\text{d}\mathbf{w}}E(\mathbf{w})=- 2(\mathbf{X}^\top\mathbf{Y}-\mathbf{X}^\top\mathbf{X} \mathbf{w}) = \begin{bmatrix}-2\sum_iy-mx_i-c \\ -2\sum_ix_i(y_i-mx_i-c)\end{bmatrix} = \begin{bmatrix}\frac{\text{d}E(m,c)}{\text{d}c} \\ \frac{\text{d}E(m,c)}{\text{d}m}\end{bmatrix}
# $$

# %% [markdown]
# ## Update Equation for Global Optimum
#
# Once again, we need to find the minimum of our objective function. Using our likelihood for multiple input regression we can now minimize for our parameter vector $\mathbf{w}$. Firstly, just as in the single input case, we seek stationary points by finding parameter vectors that solve for when the gradients are zero,
# $$
# \mathbf{0}=- 2\mathbf{X}^\top \mathbf{y} + 2\mathbf{X}^\top\mathbf{X}\mathbf{w},
# $$
# where $\mathbf{0}$ is a *vector* of zeros. Rearranging this equation we find the solution to be
# $$
# \mathbf{w} = \left[\mathbf{X}^\top \mathbf{X}\right]^{-1} \mathbf{X}^\top \mathbf{y}
# $$
# where $\mathbf{A}^{-1}$ denotes [*matrix inverse*](http://en.wikipedia.org/wiki/Invertible_matrix).
#
# ### Solving the Multivariate System
#
# The solution for $\mathbf{w}$ is given in terms of a matrix inverse, but computation of a matrix inverse requires, in itself, an algorithm to resolve it. You'll know this if you had to invert, by hand, a $3\times 3$ matrix in high school. From a numerical stability perspective, it is also best not to compute the matrix inverse directly, but rather to ask the computer to *solve* the  system of linear equations given by
# $$\mathbf{X}^\top\mathbf{X} \mathbf{w} = \mathbf{X}^\top\mathbf{y}$$
# for $\mathbf{w}$. This can be done in `numpy` using the command

# %%
np.linalg.solve?

# %% [markdown]
# so we can obtain the solution using

# %%
w = np.linalg.solve(np.dot(X.T, X), np.dot(X.T, y))
print(w)

# %% [markdown]
# We can map it back to the liner regression and plot the fit as follows

# %%
m = w[1]; c=w[0]
f_test = m*x_test + c
print(m)
print(c)
plt.plot(x_test, f_test, 'b-')
plt.plot(x, y, 'rx')

# %% [markdown]
# ## Multivariate Linear Regression
#
# A major advantage of the new system is that we can build a linear regression on a multivariate system. The matrix calculus didn't specify what the length of the vector $\mathbf{x}$ should be, or equivalently the size of the design matrix.
#
# ### Movie Body Count Data
#
# Let's load back in the movie body count data.

# %%
data = pods.datasets.movie_body_count()
movies = data['Y']

# %% [markdown]
# Let's remind ourselves of the features we've been provided with.

# %%
print(', '.join(movies.columns))

# %% [markdown]
# Now we will build a design matrix based on the numeric features: year, Body_Count, Length_Minutes in an effort to predict the rating. We build the design matrix as follows:
#
# ## Relation to Single Input System
#
# Bias as an additional feature.

# %%
select_features = ['Year', 'Body_Count', 'Length_Minutes']
X = movies.loc[:, select_features]
X['Eins'] = 1 # add a column for the offset
y = movies[['IMDB_Rating']]

# %% [markdown]
# Now let's perform a linear regression. But this time, we will create a pandas data frame for the result so we can store it in a form that we can visualise easily.

# %%
import pandas as pd
w = pd.DataFrame(data=np.linalg.solve(np.dot(X.T, X), np.dot(X.T, y)),  # solve linear regression here
                 index = X.columns,  # columns of X become rows of w
                 columns=['regression_coefficient']) # the column of X is the value of regression coefficient
w

# %% [markdown]
# We can check the residuals to see how good our estimates are

# %%
(y - np.dot(X, w)).hist()

# %% [markdown]
# Which shows our model *hasn't* yet done a great job of representation, because the spread of values is large. We can check what the rating is dominated by in terms of regression coefficients.

# %%
w

# %% [markdown]
# Although we have to be a little careful about interpretation because our input values live on different scales, however it looks like we are dominated by the bias, with a small negative effect for later films (but bear in mind the years are large, so this effect is probably larger than it looks) and a positive effect for length. So it looks like long earlier films generally do better, but the residuals are so high that we probably haven't modelled the system very well.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('ui-uNlFHoms')

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('78YNphT90-k')

# %% [markdown]
# ## Solution with QR Decomposition
#
# Performing a solve instead of a matrix inverse is the more numerically stable approach, but we can do even better. A [QR-decomposition](http://en.wikipedia.org/wiki/QR_decomposition) of a matrix factorises it into a matrix which is an orthogonal matrix $\mathbf{Q}$, so that $\mathbf{Q}^\top \mathbf{Q} = \mathbf{I}$. And a matrix which is upper triangular, $\mathbf{R}$.
# $$
# \mathbf{X}^\top \mathbf{X} \boldsymbol{\beta} = \mathbf{X}^\top \mathbf{y}
# $$
# $$
# (\mathbf{Q}\mathbf{R})^\top (\mathbf{Q}\mathbf{R})\boldsymbol{\beta} = (\mathbf{Q}\mathbf{R})^\top \mathbf{y}
# $$
# $$
# \mathbf{R}^\top (\mathbf{Q}^\top \mathbf{Q}) \mathbf{R} \boldsymbol{\beta} = \mathbf{R}^\top \mathbf{Q}^\top \mathbf{y}
# $$
# $$
# \mathbf{R}^\top \mathbf{R} \boldsymbol{\beta} = \mathbf{R}^\top \mathbf{Q}^\top \mathbf{y}
# $$
# $$
# \mathbf{R} \boldsymbol{\beta} = \mathbf{Q}^\top \mathbf{y}
# $$
# This is a more numerically stable solution because it removes the need to compute $\mathbf{X}^\top\mathbf{X}$ as an intermediate. Computing $\mathbf{X}^\top\mathbf{X}$ is a bad idea because it involves squaring all the elements of $\mathbf{X}$ and thereby potentially reducing the numerical precision with which we can represent the solution. Operating on $\mathbf{X}$ directly preserves the numerical precision of the model.
#
# This can be more particularly seen when we begin to work with *basis functions* in the next week. Some systems that can be resolved with the QR decomposition can not be resolved by using solve directly.

# %%
import scipy as sp
Q, R = np.linalg.qr(X)
w = sp.linalg.solve_triangular(R, np.dot(Q.T, y)) 
w = pd.DataFrame(w, index=X.columns)
w
